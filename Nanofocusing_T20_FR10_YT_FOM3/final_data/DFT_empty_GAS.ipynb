# %%
import meep as mp
import meep.adjoint as mpa
from meep import Animate2D
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
from meep.materials import Ag
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from PIL import Image
import matplotlib.colors as mcolors

mp.verbosity(1)
TiO2 = mp.Medium(index=2.6)
SiO2 = mp.Medium(index=1.44)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1)

# %%
os.makedirs('DFT_empty_GAS',exist_ok=True) # Create Folder

# %%
resolution = 100
design_region_resolution = int(resolution)

design_region_x_width  = 1   #100 nm
design_region_y_height = 1   #100 nm
design_region_z_height = 0.02  #20 nm or 10nm

pml_size = 1.0
pml_layers = [mp.PML(pml_size,direction=mp.Z)]

Sz_size = 0.6
Sx = design_region_x_width
Sy = design_region_y_height 
Sz = 2 * pml_size + design_region_z_height + Sz_size
cell_size = mp.Vector3(Sx, Sy, Sz)

wavelengths = np.array([1.55])     # wavelengths = np.array([1.5 ,1.55, 1.6])
frequencies = np.array([1 / 1.55])

nf = 1                 #3 #wavelengths Number

minimum_length = 0.02  # minimum length scale (microns)
eta_i = 0.5            # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55           # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e      # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)

Source_distance = -0.2

fcen   = 1 / 1.55
width  = 0.2  
fwidth = width * fcen
source_center = mp.Vector3(0,0,Source_distance)  
source_size   = mp.Vector3(design_region_x_width, design_region_y_height, 0)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)]   

Nx = int(design_region_resolution * design_region_x_width) + 1
Ny = int(design_region_resolution * design_region_y_height) + 1
Nz = 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, Ag, grid_type="U_MEAN")
design_region    = mpa.DesignRegion(
            design_variables,
            volume=mp.Volume(
            center=mp.Vector3(0,0,0),
            size=mp.Vector3(design_region_x_width, design_region_y_height, design_region_z_height),
            ),
)

def mapping(x, eta, beta):
    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_x_width,
        design_region_y_height,
        design_region_resolution,
    )
    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)
    projected_field = (npa.fliplr(projected_field) + projected_field) / 2
    projected_field = (npa.flipud(projected_field) + projected_field) / 2  # left-right symmetry    
    
    return projected_field.flatten()


geometry = [mp.Block(center=design_region.center, size=design_region.size, material=design_variables)]

kpoint = mp.Vector3()
sim = mp.Simulation(
    cell_size        = cell_size,
    boundary_layers  = pml_layers,
    geometry         = geometry,
    sources          = source,
    default_material = Air,
    k_point          = kpoint,
    symmetries       = [mp.Mirror(direction=mp.X)],
    resolution       = resolution,
    extra_materials  = [Ag],       # Introducing metal complex terms
)
#---------------------------------------------------------------------------------------------------#


#-----------------[4]---------------------------------#
monitor_position   = mp.Vector3(0, 0, 0)       # Focus position
monitor_size       = mp.Vector3(0.01,0.01,design_region_z_height)     # Focus Size//////0.11
FourierFields_x    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ex,yee_grid=True)
FourierFields_y    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ey,yee_grid=True)
FourierFields_z    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list            = [FourierFields_x,FourierFields_y,FourierFields_z]


def J(fields_x,fields_y,fields_z):
    ET_x = 0
    ET_y = 0
    ET_z = 0
    ET_x_length = fields_x.shape[1]
    ET_y_length = fields_y.shape[1]
    ET_z_length = fields_z.shape[1]
    for k in range(0,ET_x_length):
        ET_x = ET_x + npa.abs(fields_x[:,k]) ** 2
    for k in range(0,ET_y_length):
        ET_y = ET_y + npa.abs(fields_y[:,k]) ** 2
    for k in range(0,ET_z_length):
        ET_z = ET_z + npa.abs(fields_z[:,k]) ** 2
    ET = ( (npa.mean(ET_x)) + (npa.mean(ET_y)) + (npa.mean(ET_z)) ) ** (1/2)  
    return ET


opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decimation_factor = 1 ,           # KEY BUG!!
    maximum_run_time=50,
)

# %%
evaluation_history = np.load('Post_evaluation_history.npy')
beta_A  = np.load("Post_beta_scale_array.npy")
eta_A   = np.load("Post_eta_i_array.npy")
cur_A   = np.load("Post_cur_beta_array.npy")
x_A     = np.load("Post_x_array.npy")

# %%
plt.figure()
plt.plot(evaluation_history, "o-")

for i in range(1,13):
    plt.axvline(x=15*i, color='purple', linestyle='--', label='x=3')
plt.grid(True)
plt.xlim(0)
plt.ylim(0)
plt.xlabel("Iteration")
plt.ylabel("FOM")
# Out:
# Text(0, 0.5, 'FOM')

# %%
opt.update_design([mapping(x_A, eta_A, cur_A/beta_A)])  # cur_beta/beta_scale is the final beta in the optimization.
plt.figure(figsize=(5,5))
ax = plt.gca()
opt.plot2D(
    False,
    ax=ax,
    plot_sources_flag=False,
    plot_monitors_flag=False,
    plot_boundaries_flag=False,
    output_plane = mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(design_region_x_width, design_region_y_height, 0))
)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
plt.close()
# Out:
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %%
opt.sim = mp.Simulation(
    cell_size=mp.Vector3(Sx, Sy ,Sz),
    boundary_layers=pml_layers,
    geometry=[], ##_empty
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point=kpoint,
    #symmetries=[mp.Mirror(direction=mp.X)],
    extra_materials = [Ag],
)
#src = mp.ContinuousSource(frequency=frequencies[0], fwidth=0.01 ,is_integrated=True)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)] 
opt.sim.change_sources(source)

dft_fields_xz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(Sx,0,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_yz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(0,Sy,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_xyz12 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False
                                )

dft_fields_xyz00 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False 
                                )

dft_fields_x0yz0 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(0,Sy,0),
                                yee_grid=False
                                )


#opt.sim.run(until_after_sources = 0) 
opt.sim.run(until_after_sources=mp.stop_when_dft_decayed(
            tol=1e-11,
            minimum_run_time=0,
            maximum_run_time=50)
            )
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161171 s
# Working in 3D dimensions.
# Computational cell is 1 x 1 x 2.62 with resolution 100
# time for set_epsilon = 4.23013 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 5 (time=0.025), 0.818974 s/step
# on time step 25 (time=0.125), 0.209168 s/step
# on time step 45 (time=0.225), 0.207089 s/step
# on time step 64 (time=0.32), 0.211586 s/step
# on time step 83 (time=0.415), 0.211965 s/step
# on time step 103 (time=0.515), 0.21006 s/step
# on time step 122 (time=0.61), 0.213187 s/step
# on time step 142 (time=0.71), 0.2113 s/step
# on time step 161 (time=0.805), 0.212472 s/step
# on time step 180 (time=0.9), 0.210579 s/step
# on time step 200 (time=1), 0.208947 s/step
# on time step 219 (time=1.095), 0.213021 s/step
# on time step 239 (time=1.195), 0.208496 s/step
# on time step 259 (time=1.295), 0.210453 s/step
# on time step 279 (time=1.395), 0.210455 s/step
# on time step 299 (time=1.495), 0.201454 s/step
# on time step 331 (time=1.655), 0.126784 s/step
# on time step 356 (time=1.78), 0.16084 s/step
# on time step 380 (time=1.9), 0.171602 s/step
# on time step 403 (time=2.015), 0.175867 s/step
# on time step 427 (time=2.135), 0.172407 s/step
# on time step 451 (time=2.255), 0.171648 s/step
# on time step 475 (time=2.375), 0.17121 s/step
# on time step 498 (time=2.49), 0.175591 s/step
# on time step 522 (time=2.61), 0.172194 s/step
# on time step 545 (time=2.725), 0.175569 s/step
# on time step 569 (time=2.845), 0.170857 s/step
# on time step 593 (time=2.965), 0.171218 s/step
# on time step 617 (time=3.085), 0.17125 s/step
# on time step 641 (time=3.205), 0.172575 s/step
# on time step 665 (time=3.325), 0.170775 s/step
# on time step 689 (time=3.445), 0.174068 s/step
# on time step 713 (time=3.565), 0.172451 s/step
# on time step 737 (time=3.685), 0.172447 s/step
# on time step 761 (time=3.805), 0.170536 s/step
# on time step 785 (time=3.925), 0.171982 s/step
# on time step 809 (time=4.045), 0.171305 s/step
# on time step 833 (time=4.165), 0.170942 s/step
# on time step 857 (time=4.285), 0.171008 s/step
# on time step 881 (time=4.405), 0.171064 s/step
# on time step 905 (time=4.525), 0.173391 s/step
# on time step 929 (time=4.645), 0.171234 s/step
# on time step 953 (time=4.765), 0.170226 s/step
# on time step 977 (time=4.885), 0.170799 s/step
# on time step 1001 (time=5.005), 0.171238 s/step
# on time step 1025 (time=5.125), 0.170462 s/step
# on time step 1049 (time=5.245), 0.170238 s/step
# on time step 1073 (time=5.365), 0.170279 s/step
# on time step 1096 (time=5.48), 0.174492 s/step
# on time step 1124 (time=5.62), 0.143108 s/step
# on time step 1151 (time=5.755), 0.151161 s/step
# on time step 1175 (time=5.875), 0.167181 s/step
# on time step 1199 (time=5.995), 0.167875 s/step
# on time step 1224 (time=6.12), 0.164846 s/step
# on time step 1249 (time=6.245), 0.165494 s/step
# on time step 1274 (time=6.37), 0.164362 s/step
# on time step 1299 (time=6.495), 0.16561 s/step
# on time step 1324 (time=6.62), 0.164745 s/step
# on time step 1349 (time=6.745), 0.164541 s/step
# on time step 1374 (time=6.87), 0.165705 s/step
# on time step 1399 (time=6.995), 0.165052 s/step
# on time step 1423 (time=7.115), 0.167115 s/step
# on time step 1447 (time=7.235), 0.166929 s/step
# on time step 1472 (time=7.36), 0.165527 s/step
# on time step 1497 (time=7.485), 0.164857 s/step
# on time step 1522 (time=7.61), 0.165094 s/step
# on time step 1546 (time=7.73), 0.167719 s/step
# on time step 1570 (time=7.85), 0.166768 s/step
# on time step 1595 (time=7.975), 0.166076 s/step
# on time step 1620 (time=8.1), 0.166503 s/step
# on time step 1644 (time=8.22), 0.17085 s/step
# on time step 1668 (time=8.34), 0.167609 s/step
# on time step 1692 (time=8.46), 0.168565 s/step
# on time step 1716 (time=8.58), 0.168351 s/step
# on time step 1740 (time=8.7), 0.170399 s/step
# on time step 1765 (time=8.825), 0.165106 s/step
# on time step 1790 (time=8.95), 0.166314 s/step
# on time step 1815 (time=9.075), 0.165675 s/step
# on time step 1840 (time=9.2), 0.165365 s/step
# on time step 1862 (time=9.31), 0.182079 s/step
# on time step 1887 (time=9.435), 0.166117 s/step
# on time step 1911 (time=9.555), 0.171075 s/step
# on time step 1933 (time=9.665), 0.184139 s/step
# on time step 1956 (time=9.78), 0.177167 s/step
# on time step 1981 (time=9.905), 0.166167 s/step
# on time step 2005 (time=10.025), 0.167987 s/step
# on time step 2030 (time=10.15), 0.165895 s/step
# on time step 2055 (time=10.275), 0.164355 s/step
# on time step 2079 (time=10.395), 0.167394 s/step
# on time step 2104 (time=10.52), 0.164307 s/step
# on time step 2129 (time=10.645), 0.165203 s/step
# on time step 2154 (time=10.77), 0.165359 s/step
# on time step 2179 (time=10.895), 0.165227 s/step
# on time step 2204 (time=11.02), 0.165966 s/step
# on time step 2229 (time=11.145), 0.166138 s/step
# on time step 2254 (time=11.27), 0.165396 s/step
# on time step 2280 (time=11.4), 0.156437 s/step
# on time step 2302 (time=11.51), 0.188352 s/step
# on time step 2322 (time=11.61), 0.202524 s/step
# on time step 2342 (time=11.71), 0.202841 s/step
# on time step 2363 (time=11.815), 0.195755 s/step
# on time step 2383 (time=11.915), 0.204344 s/step
# on time step 2404 (time=12.02), 0.198308 s/step
# on time step 2425 (time=12.125), 0.19998 s/step
# on time step 2446 (time=12.23), 0.197587 s/step
# on time step 2467 (time=12.335), 0.199448 s/step
# on time step 2488 (time=12.44), 0.198406 s/step
# on time step 2509 (time=12.545), 0.197206 s/step
# on time step 2530 (time=12.65), 0.196359 s/step
# on time step 2551 (time=12.755), 0.197666 s/step
# on time step 2572 (time=12.86), 0.199775 s/step
# on time step 2592 (time=12.96), 0.20198 s/step
# on time step 2613 (time=13.065), 0.19814 s/step
# on time step 2634 (time=13.17), 0.197001 s/step
# on time step 2655 (time=13.275), 0.197566 s/step
# on time step 2676 (time=13.38), 0.195605 s/step
# on time step 2697 (time=13.485), 0.197407 s/step
# on time step 2718 (time=13.59), 0.195148 s/step
# on time step 2739 (time=13.695), 0.193002 s/step
# on time step 2760 (time=13.8), 0.195444 s/step
# on time step 2781 (time=13.905), 0.19991 s/step
# on time step 2801 (time=14.005), 0.202716 s/step
# on time step 2821 (time=14.105), 0.202011 s/step
# on time step 2841 (time=14.205), 0.202576 s/step
# on time step 2861 (time=14.305), 0.202679 s/step
# on time step 2881 (time=14.405), 0.201249 s/step
# on time step 2901 (time=14.505), 0.207375 s/step
# on time step 2922 (time=14.61), 0.195981 s/step
# on time step 2942 (time=14.71), 0.201902 s/step
# on time step 2962 (time=14.81), 0.203545 s/step
# on time step 2982 (time=14.91), 0.203348 s/step
# on time step 3002 (time=15.01), 0.204169 s/step
# on time step 3022 (time=15.11), 0.203517 s/step
# on time step 3042 (time=15.21), 0.202701 s/step
# on time step 3062 (time=15.31), 0.204476 s/step
# on time step 3082 (time=15.41), 0.20364 s/step
# on time step 3102 (time=15.51), 0.207876 s/step
# on time step 3122 (time=15.61), 0.20628 s/step
# on time step 3142 (time=15.71), 0.209827 s/step
# on time step 3162 (time=15.81), 0.207222 s/step
# on time step 3182 (time=15.91), 0.206054 s/step
# on time step 3202 (time=16.01), 0.206659 s/step
# on time step 3222 (time=16.11), 0.20618 s/step
# on time step 3242 (time=16.21), 0.202129 s/step
# on time step 3262 (time=16.31), 0.203789 s/step
# on time step 3282 (time=16.41), 0.202829 s/step
# on time step 3302 (time=16.51), 0.202574 s/step
# on time step 3322 (time=16.61), 0.201135 s/step
# on time step 3342 (time=16.71), 0.205633 s/step
# on time step 3362 (time=16.81), 0.206649 s/step
# on time step 3387 (time=16.935), 0.160438 s/step
# on time step 3416 (time=17.08), 0.140814 s/step
# on time step 3456 (time=17.28), 0.101953 s/step
# on time step 3476 (time=17.38), 0.201889 s/step
# on time step 3495 (time=17.475), 0.218039 s/step
# on time step 3513 (time=17.565), 0.223066 s/step
# on time step 3532 (time=17.66), 0.221635 s/step
# on time step 3550 (time=17.75), 0.222418 s/step
# on time step 3568 (time=17.84), 0.222912 s/step
# on time step 3586 (time=17.93), 0.223473 s/step
# on time step 3605 (time=18.025), 0.221313 s/step
# on time step 3624 (time=18.12), 0.221038 s/step
# on time step 3642 (time=18.21), 0.222851 s/step
# on time step 3660 (time=18.3), 0.223168 s/step
# on time step 3679 (time=18.395), 0.220521 s/step
# on time step 3698 (time=18.49), 0.220332 s/step
# on time step 3717 (time=18.585), 0.21889 s/step
# on time step 3736 (time=18.68), 0.217723 s/step
# on time step 3755 (time=18.775), 0.218318 s/step
# on time step 3774 (time=18.87), 0.219181 s/step
# on time step 3793 (time=18.965), 0.218527 s/step
# on time step 3812 (time=19.06), 0.220202 s/step
# on time step 3831 (time=19.155), 0.217133 s/step
# on time step 3850 (time=19.25), 0.218713 s/step
# on time step 3869 (time=19.345), 0.218528 s/step
# on time step 3888 (time=19.44), 0.2187 s/step
# on time step 3907 (time=19.535), 0.219068 s/step
# on time step 3926 (time=19.63), 0.219839 s/step
# on time step 3945 (time=19.725), 0.218212 s/step
# on time step 3964 (time=19.82), 0.218838 s/step
# on time step 3983 (time=19.915), 0.21932 s/step
# on time step 4002 (time=20.01), 0.220059 s/step
# on time step 4021 (time=20.105), 0.217797 s/step
# on time step 4040 (time=20.2), 0.219385 s/step
# on time step 4059 (time=20.295), 0.218396 s/step
# on time step 4078 (time=20.39), 0.218666 s/step
# on time step 4097 (time=20.485), 0.219132 s/step
# on time step 4116 (time=20.58), 0.218933 s/step
# on time step 4135 (time=20.675), 0.219204 s/step
# on time step 4154 (time=20.77), 0.216969 s/step
# on time step 4173 (time=20.865), 0.216065 s/step
# on time step 4192 (time=20.96), 0.216772 s/step
# on time step 4210 (time=21.05), 0.22359 s/step
# on time step 4229 (time=21.145), 0.219152 s/step
# on time step 4248 (time=21.24), 0.218745 s/step
# on time step 4267 (time=21.335), 0.218317 s/step
# on time step 4286 (time=21.43), 0.218785 s/step
# on time step 4305 (time=21.525), 0.219017 s/step
# on time step 4324 (time=21.62), 0.218325 s/step
# on time step 4343 (time=21.715), 0.217801 s/step
# on time step 4362 (time=21.81), 0.219018 s/step
# on time step 4381 (time=21.905), 0.218552 s/step
# on time step 4400 (time=22), 0.218332 s/step
# on time step 4419 (time=22.095), 0.215942 s/step
# on time step 4439 (time=22.195), 0.205224 s/step
# on time step 4462 (time=22.31), 0.177868 s/step
# on time step 4481 (time=22.405), 0.221866 s/step
# on time step 4499 (time=22.495), 0.233923 s/step
# on time step 4517 (time=22.585), 0.233986 s/step
# on time step 4534 (time=22.67), 0.23565 s/step
# on time step 4551 (time=22.755), 0.236092 s/step
# on time step 4568 (time=22.84), 0.239365 s/step
# on time step 4585 (time=22.925), 0.239745 s/step
# on time step 4602 (time=23.01), 0.239201 s/step
# on time step 4619 (time=23.095), 0.239432 s/step
# on time step 4636 (time=23.18), 0.240849 s/step
# on time step 4653 (time=23.265), 0.238413 s/step
# on time step 4670 (time=23.35), 0.238348 s/step
# on time step 4687 (time=23.435), 0.237893 s/step
# on time step 4705 (time=23.525), 0.230129 s/step
# on time step 4723 (time=23.615), 0.233772 s/step
# on time step 4741 (time=23.705), 0.234134 s/step
# on time step 4759 (time=23.795), 0.23495 s/step
# on time step 4777 (time=23.885), 0.234401 s/step
# on time step 4795 (time=23.975), 0.234799 s/step
# on time step 4813 (time=24.065), 0.234449 s/step
# on time step 4831 (time=24.155), 0.23406 s/step
# on time step 4848 (time=24.24), 0.241675 s/step
# on time step 4865 (time=24.325), 0.246989 s/step
# on time step 4882 (time=24.41), 0.247589 s/step
# on time step 4899 (time=24.495), 0.247618 s/step
# on time step 4916 (time=24.58), 0.249323 s/step
# on time step 4936 (time=24.68), 0.201865 s/step
# on time step 4956 (time=24.78), 0.20581 s/step
# on time step 4973 (time=24.865), 0.24382 s/step
# on time step 4990 (time=24.95), 0.242778 s/step
# on time step 5007 (time=25.035), 0.238744 s/step
# on time step 5024 (time=25.12), 0.238297 s/step
# on time step 5042 (time=25.21), 0.235154 s/step
# on time step 5060 (time=25.3), 0.234637 s/step
# on time step 5078 (time=25.39), 0.233864 s/step
# on time step 5095 (time=25.475), 0.236915 s/step
# on time step 5113 (time=25.565), 0.234495 s/step
# on time step 5131 (time=25.655), 0.235565 s/step
# on time step 5148 (time=25.74), 0.237138 s/step
# on time step 5165 (time=25.825), 0.236505 s/step
# on time step 5182 (time=25.91), 0.235549 s/step
# on time step 5199 (time=25.995), 0.237898 s/step
# on time step 5216 (time=26.08), 0.236469 s/step
# on time step 5233 (time=26.165), 0.242123 s/step
# on time step 5250 (time=26.25), 0.236468 s/step
# on time step 5269 (time=26.345), 0.217441 s/step
# on time step 5297 (time=26.485), 0.142893 s/step
# on time step 5318 (time=26.59), 0.20167 s/step
# on time step 5334 (time=26.67), 0.251086 s/step
# on time step 5351 (time=26.755), 0.244375 s/step
# on time step 5367 (time=26.835), 0.25201 s/step
# on time step 5383 (time=26.915), 0.257842 s/step
# on time step 5399 (time=26.995), 0.254093 s/step
# on time step 5415 (time=27.075), 0.25553 s/step
# on time step 5431 (time=27.155), 0.252389 s/step
# on time step 5447 (time=27.235), 0.257489 s/step
# on time step 5463 (time=27.315), 0.251172 s/step
# on time step 5479 (time=27.395), 0.258794 s/step
# on time step 5495 (time=27.475), 0.253588 s/step
# on time step 5511 (time=27.555), 0.251469 s/step
# on time step 5527 (time=27.635), 0.256617 s/step
# on time step 5543 (time=27.715), 0.252623 s/step
# on time step 5559 (time=27.795), 0.251481 s/step
# on time step 5575 (time=27.875), 0.252684 s/step
# on time step 5591 (time=27.955), 0.256885 s/step
# on time step 5607 (time=28.035), 0.25434 s/step
# on time step 5623 (time=28.115), 0.252714 s/step
# on time step 5639 (time=28.195), 0.251091 s/step
# on time step 5655 (time=28.275), 0.252364 s/step
# on time step 5672 (time=28.36), 0.237077 s/step
# on time step 5690 (time=28.45), 0.232102 s/step
# on time step 5708 (time=28.54), 0.223722 s/step
# on time step 5725 (time=28.625), 0.240774 s/step
# on time step 5742 (time=28.71), 0.238178 s/step
# on time step 5759 (time=28.795), 0.241513 s/step
# on time step 5776 (time=28.88), 0.249314 s/step
# on time step 5792 (time=28.96), 0.251318 s/step
# on time step 5809 (time=29.045), 0.248877 s/step
# on time step 5827 (time=29.135), 0.226641 s/step
# on time step 5856 (time=29.28), 0.140629 s/step
# on time step 5881 (time=29.405), 0.162016 s/step
# on time step 5906 (time=29.53), 0.162696 s/step
# on time step 5931 (time=29.655), 0.16584 s/step
# on time step 5956 (time=29.78), 0.164489 s/step
# on time step 5981 (time=29.905), 0.162569 s/step
# on time step 6006 (time=30.03), 0.162574 s/step
# on time step 6031 (time=30.155), 0.163209 s/step
# on time step 6056 (time=30.28), 0.162753 s/step
# on time step 6081 (time=30.405), 0.162375 s/step
# on time step 6106 (time=30.53), 0.1637 s/step
# on time step 6130 (time=30.65), 0.167201 s/step
# on time step 6155 (time=30.775), 0.165182 s/step
# on time step 6180 (time=30.9), 0.164179 s/step
# on time step 6205 (time=31.025), 0.163755 s/step
# on time step 6231 (time=31.155), 0.156897 s/step
# on time step 6257 (time=31.285), 0.160007 s/step
# on time step 6282 (time=31.41), 0.165033 s/step
# on time step 6307 (time=31.535), 0.16074 s/step
# on time step 6332 (time=31.66), 0.161006 s/step
# on time step 6357 (time=31.785), 0.160487 s/step
# on time step 6381 (time=31.905), 0.168905 s/step
# on time step 6406 (time=32.03), 0.164599 s/step
# on time step 6430 (time=32.15), 0.167247 s/step
# on time step 6455 (time=32.275), 0.162831 s/step
# on time step 6480 (time=32.4), 0.163258 s/step
# on time step 6505 (time=32.525), 0.163541 s/step
# on time step 6529 (time=32.645), 0.168639 s/step
# on time step 6554 (time=32.77), 0.164717 s/step
# on time step 6579 (time=32.895), 0.163344 s/step
# on time step 6604 (time=33.02), 0.163484 s/step
# on time step 6629 (time=33.145), 0.163449 s/step
# on time step 6654 (time=33.27), 0.164053 s/step
# on time step 6678 (time=33.39), 0.169708 s/step
# on time step 6703 (time=33.515), 0.16462 s/step
# on time step 6727 (time=33.635), 0.166954 s/step
# on time step 6752 (time=33.76), 0.163176 s/step
# on time step 6778 (time=33.89), 0.156617 s/step
# on time step 6804 (time=34.02), 0.157846 s/step
# on time step 6830 (time=34.15), 0.158332 s/step
# on time step 6856 (time=34.28), 0.158779 s/step
# on time step 6882 (time=34.41), 0.157911 s/step
# on time step 6908 (time=34.54), 0.157629 s/step
# on time step 6934 (time=34.67), 0.157958 s/step
# on time step 6960 (time=34.8), 0.158228 s/step
# on time step 6986 (time=34.93), 0.15663 s/step
# on time step 7012 (time=35.06), 0.156852 s/step
# on time step 7038 (time=35.19), 0.156729 s/step
# on time step 7063 (time=35.315), 0.160083 s/step
# on time step 7091 (time=35.455), 0.145211 s/step
# on time step 7117 (time=35.585), 0.161332 s/step
# on time step 7137 (time=35.685), 0.210103 s/step
# on time step 7157 (time=35.785), 0.208698 s/step
# on time step 7177 (time=35.885), 0.208607 s/step
# on time step 7197 (time=35.985), 0.20864 s/step
# on time step 7217 (time=36.085), 0.209109 s/step
# on time step 7237 (time=36.185), 0.208656 s/step
# on time step 7257 (time=36.285), 0.208692 s/step
# on time step 7277 (time=36.385), 0.208369 s/step
# on time step 7297 (time=36.485), 0.208562 s/step
# on time step 7317 (time=36.585), 0.208762 s/step
# on time step 7337 (time=36.685), 0.208571 s/step
# on time step 7357 (time=36.785), 0.20913 s/step
# on time step 7377 (time=36.885), 0.209086 s/step
# on time step 7397 (time=36.985), 0.20944 s/step
# on time step 7416 (time=37.08), 0.212071 s/step
# on time step 7436 (time=37.18), 0.208312 s/step
# on time step 7456 (time=37.28), 0.210354 s/step
# on time step 7476 (time=37.38), 0.208056 s/step
# on time step 7496 (time=37.48), 0.209117 s/step
# on time step 7516 (time=37.58), 0.207843 s/step
# on time step 7536 (time=37.68), 0.208757 s/step
# on time step 7556 (time=37.78), 0.20628 s/step
# on time step 7576 (time=37.88), 0.205103 s/step
# on time step 7596 (time=37.98), 0.208097 s/step
# on time step 7616 (time=38.08), 0.206479 s/step
# on time step 7636 (time=38.18), 0.208149 s/step
# on time step 7656 (time=38.28), 0.207325 s/step
# on time step 7676 (time=38.38), 0.208214 s/step
# on time step 7696 (time=38.48), 0.207654 s/step
# on time step 7716 (time=38.58), 0.207332 s/step
# on time step 7736 (time=38.68), 0.207384 s/step
# on time step 7756 (time=38.78), 0.20751 s/step
# on time step 7776 (time=38.88), 0.207808 s/step
# on time step 7796 (time=38.98), 0.208472 s/step
# on time step 7816 (time=39.08), 0.21261 s/step
# on time step 7836 (time=39.18), 0.208031 s/step
# on time step 7856 (time=39.28), 0.207342 s/step
# on time step 7876 (time=39.38), 0.20878 s/step
# on time step 7896 (time=39.48), 0.207896 s/step
# on time step 7916 (time=39.58), 0.207683 s/step
# on time step 7936 (time=39.68), 0.206949 s/step
# on time step 7956 (time=39.78), 0.208633 s/step
# on time step 7976 (time=39.88), 0.20856 s/step
# on time step 7996 (time=39.98), 0.207093 s/step
# on time step 8016 (time=40.08), 0.207758 s/step
# on time step 8036 (time=40.18), 0.208583 s/step
# on time step 8056 (time=40.28), 0.207769 s/step
# on time step 8076 (time=40.38), 0.207894 s/step
# on time step 8096 (time=40.48), 0.208287 s/step
# on time step 8116 (time=40.58), 0.207415 s/step
# on time step 8141 (time=40.705), 0.161156 s/step
# on time step 8169 (time=40.845), 0.143285 s/step
# on time step 8205 (time=41.025), 0.112953 s/step
# on time step 8225 (time=41.125), 0.203112 s/step
# on time step 8244 (time=41.22), 0.218538 s/step
# on time step 8263 (time=41.315), 0.218068 s/step
# on time step 8282 (time=41.41), 0.218443 s/step
# on time step 8301 (time=41.505), 0.220482 s/step
# on time step 8320 (time=41.6), 0.216174 s/step
# on time step 8339 (time=41.695), 0.218737 s/step
# on time step 8358 (time=41.79), 0.216907 s/step
# on time step 8377 (time=41.885), 0.218009 s/step
# on time step 8396 (time=41.98), 0.219265 s/step
# on time step 8415 (time=42.075), 0.217672 s/step
# on time step 8434 (time=42.17), 0.216877 s/step
# on time step 8453 (time=42.265), 0.216877 s/step
# on time step 8472 (time=42.36), 0.216153 s/step
# on time step 8491 (time=42.455), 0.216142 s/step
# on time step 8510 (time=42.55), 0.217326 s/step
# on time step 8529 (time=42.645), 0.217535 s/step
# on time step 8548 (time=42.74), 0.218427 s/step
# on time step 8567 (time=42.835), 0.217109 s/step
# on time step 8586 (time=42.93), 0.216634 s/step
# on time step 8605 (time=43.025), 0.217668 s/step
# on time step 8624 (time=43.12), 0.21577 s/step
# on time step 8643 (time=43.215), 0.218101 s/step
# on time step 8662 (time=43.31), 0.217377 s/step
# on time step 8681 (time=43.405), 0.21747 s/step
# on time step 8700 (time=43.5), 0.218844 s/step
# on time step 8719 (time=43.595), 0.218472 s/step
# on time step 8738 (time=43.69), 0.216397 s/step
# on time step 8757 (time=43.785), 0.21472 s/step
# on time step 8776 (time=43.88), 0.216992 s/step
# on time step 8795 (time=43.975), 0.218593 s/step
# on time step 8814 (time=44.07), 0.220776 s/step
# on time step 8833 (time=44.165), 0.218978 s/step
# on time step 8852 (time=44.26), 0.219351 s/step
# on time step 8871 (time=44.355), 0.217811 s/step
# on time step 8890 (time=44.45), 0.210652 s/step
# on time step 8909 (time=44.545), 0.219043 s/step
# on time step 8928 (time=44.64), 0.216476 s/step
# on time step 8947 (time=44.735), 0.220698 s/step
# on time step 8966 (time=44.83), 0.217394 s/step
# on time step 8985 (time=44.925), 0.220077 s/step
# on time step 9004 (time=45.02), 0.219219 s/step
# on time step 9023 (time=45.115), 0.215578 s/step
# on time step 9042 (time=45.21), 0.221096 s/step
# on time step 9061 (time=45.305), 0.214763 s/step
# on time step 9080 (time=45.4), 0.216889 s/step
# on time step 9099 (time=45.495), 0.218743 s/step
# on time step 9118 (time=45.59), 0.219539 s/step
# on time step 9137 (time=45.685), 0.218249 s/step
# on time step 9156 (time=45.78), 0.219156 s/step
# on time step 9175 (time=45.875), 0.213175 s/step
# on time step 9194 (time=45.97), 0.2128 s/step
# on time step 9217 (time=46.085), 0.176581 s/step
# on time step 9240 (time=46.2), 0.182192 s/step
# on time step 9260 (time=46.3), 0.208566 s/step
# on time step 9279 (time=46.395), 0.219903 s/step
# on time step 9298 (time=46.49), 0.220605 s/step
# on time step 9317 (time=46.585), 0.220311 s/step
# on time step 9336 (time=46.68), 0.220669 s/step
# on time step 9355 (time=46.775), 0.21963 s/step
# on time step 9374 (time=46.87), 0.221145 s/step
# on time step 9393 (time=46.965), 0.220881 s/step
# on time step 9412 (time=47.06), 0.220797 s/step
# on time step 9431 (time=47.155), 0.219933 s/step
# on time step 9450 (time=47.25), 0.220303 s/step
# on time step 9468 (time=47.34), 0.222357 s/step
# on time step 9487 (time=47.435), 0.219992 s/step
# on time step 9506 (time=47.53), 0.220786 s/step
# on time step 9524 (time=47.62), 0.222375 s/step
# on time step 9543 (time=47.715), 0.219455 s/step
# on time step 9562 (time=47.81), 0.219034 s/step
# on time step 9580 (time=47.9), 0.222654 s/step
# on time step 9599 (time=47.995), 0.221681 s/step
# on time step 9617 (time=48.085), 0.223155 s/step
# on time step 9636 (time=48.18), 0.220314 s/step
# on time step 9654 (time=48.27), 0.224408 s/step
# on time step 9673 (time=48.365), 0.213194 s/step
# on time step 9705 (time=48.525), 0.126981 s/step
# on time step 9722 (time=48.61), 0.248359 s/step
# on time step 9738 (time=48.69), 0.25008 s/step
# on time step 9755 (time=48.775), 0.249025 s/step
# on time step 9772 (time=48.86), 0.248387 s/step
# on time step 9789 (time=48.945), 0.249341 s/step
# on time step 9805 (time=49.025), 0.250341 s/step
# on time step 9822 (time=49.11), 0.248902 s/step
# on time step 9839 (time=49.195), 0.248332 s/step
# on time step 9856 (time=49.28), 0.249755 s/step
# on time step 9873 (time=49.365), 0.249709 s/step
# on time step 9890 (time=49.45), 0.249853 s/step
# on time step 9907 (time=49.535), 0.246196 s/step
# on time step 9924 (time=49.62), 0.248298 s/step
# on time step 9940 (time=49.7), 0.250171 s/step
# on time step 9957 (time=49.785), 0.249096 s/step
# on time step 9974 (time=49.87), 0.24795 s/step
# on time step 9991 (time=49.955), 0.24846 s/step
# on time step 10008 (time=50.04), 0.248578 s/step
# on time step 10025 (time=50.125), 0.248159 s/step
# on time step 10042 (time=50.21), 0.249045 s/step
# on time step 10059 (time=50.295), 0.248655 s/step
# on time step 10076 (time=50.38), 0.247644 s/step
# on time step 10092 (time=50.46), 0.250434 s/step
# on time step 10109 (time=50.545), 0.248483 s/step
# on time step 10126 (time=50.63), 0.247722 s/step
# on time step 10143 (time=50.715), 0.249191 s/step
# on time step 10160 (time=50.8), 0.247961 s/step
# on time step 10176 (time=50.88), 0.250012 s/step
# on time step 10193 (time=50.965), 0.248393 s/step
# on time step 10215 (time=51.075), 0.209076 s/step
# on time step 10243 (time=51.215), 0.145339 s/step
# on time step 10264 (time=51.32), 0.200028 s/step
# on time step 10281 (time=51.405), 0.237701 s/step
# on time step 10298 (time=51.49), 0.2361 s/step
# on time step 10315 (time=51.575), 0.237099 s/step
# on time step 10332 (time=51.66), 0.237154 s/step
# on time step 10349 (time=51.745), 0.238598 s/step
# on time step 10366 (time=51.83), 0.237859 s/step
# on time step 10383 (time=51.915), 0.237936 s/step
# on time step 10400 (time=52), 0.237366 s/step
# on time step 10417 (time=52.085), 0.237891 s/step
# on time step 10434 (time=52.17), 0.237811 s/step
# on time step 10451 (time=52.255), 0.23639 s/step
# on time step 10468 (time=52.34), 0.237487 s/step
# on time step 10485 (time=52.425), 0.241378 s/step
# on time step 10502 (time=52.51), 0.23787 s/step
# on time step 10519 (time=52.595), 0.238623 s/step
# on time step 10536 (time=52.68), 0.239182 s/step
# on time step 10553 (time=52.765), 0.238485 s/step
# on time step 10571 (time=52.855), 0.231694 s/step
# on time step 10590 (time=52.95), 0.218743 s/step
# on time step 10608 (time=53.04), 0.226835 s/step
# on time step 10625 (time=53.125), 0.235981 s/step
# on time step 10656 (time=53.28), 0.132639 s/step
# on time step 10680 (time=53.4), 0.169617 s/step
# on time step 10703 (time=53.515), 0.174072 s/step
# on time step 10726 (time=53.63), 0.175043 s/step
# on time step 10749 (time=53.745), 0.174852 s/step
# on time step 10773 (time=53.865), 0.172294 s/step
# on time step 10796 (time=53.98), 0.174382 s/step
# on time step 10819 (time=54.095), 0.174621 s/step
# on time step 10842 (time=54.21), 0.175364 s/step
# on time step 10865 (time=54.325), 0.174333 s/step
# on time step 10888 (time=54.44), 0.175045 s/step
# on time step 10911 (time=54.555), 0.174062 s/step
# on time step 10934 (time=54.67), 0.175357 s/step
# on time step 10957 (time=54.785), 0.174504 s/step
# on time step 10980 (time=54.9), 0.175145 s/step
# on time step 11003 (time=55.015), 0.175683 s/step
# on time step 11026 (time=55.13), 0.174411 s/step
# on time step 11049 (time=55.245), 0.174455 s/step
# on time step 11073 (time=55.365), 0.173574 s/step
# on time step 11096 (time=55.48), 0.174951 s/step
# on time step 11119 (time=55.595), 0.174587 s/step
# on time step 11142 (time=55.71), 0.174145 s/step
# on time step 11166 (time=55.83), 0.173587 s/step
# on time step 11189 (time=55.945), 0.174674 s/step
# on time step 11212 (time=56.06), 0.174712 s/step
# on time step 11235 (time=56.175), 0.174929 s/step
# on time step 11258 (time=56.29), 0.174752 s/step
# on time step 11281 (time=56.405), 0.174909 s/step
# on time step 11304 (time=56.52), 0.175224 s/step
# on time step 11327 (time=56.635), 0.174201 s/step
# on time step 11350 (time=56.75), 0.175115 s/step
# on time step 11373 (time=56.865), 0.174431 s/step
# on time step 11396 (time=56.98), 0.17508 s/step
# on time step 11419 (time=57.095), 0.174356 s/step
# on time step 11442 (time=57.21), 0.174861 s/step
# on time step 11466 (time=57.33), 0.173762 s/step
# on time step 11489 (time=57.445), 0.175042 s/step
# on time step 11512 (time=57.56), 0.174358 s/step
# on time step 11535 (time=57.675), 0.17476 s/step
# on time step 11558 (time=57.79), 0.175844 s/step
# on time step 11581 (time=57.905), 0.176068 s/step
# on time step 11604 (time=58.02), 0.174186 s/step
# on time step 11628 (time=58.14), 0.173258 s/step
# on time step 11651 (time=58.255), 0.174411 s/step
# on time step 11674 (time=58.37), 0.175186 s/step
# on time step 11698 (time=58.49), 0.172835 s/step
# on time step 11721 (time=58.605), 0.175108 s/step
# on time step 11744 (time=58.72), 0.175961 s/step
# on time step 11767 (time=58.835), 0.175069 s/step
# on time step 11790 (time=58.95), 0.175891 s/step
# on time step 11813 (time=59.065), 0.175208 s/step
# on time step 11836 (time=59.18), 0.176217 s/step
# on time step 11859 (time=59.295), 0.178968 s/step
# on time step 11882 (time=59.41), 0.176483 s/step
# on time step 11905 (time=59.525), 0.176219 s/step
# on time step 11928 (time=59.64), 0.176777 s/step
# on time step 11951 (time=59.755), 0.176045 s/step
# on time step 11980 (time=59.9), 0.140515 s/step
# on time step 11999 (time=59.995), 0.215453 s/step
# on time step 12015 (time=60.075), 0.252825 s/step
# on time step 12031 (time=60.155), 0.260453 s/step
# on time step 12047 (time=60.235), 0.257614 s/step
# on time step 12063 (time=60.315), 0.254957 s/step
# on time step 12079 (time=60.395), 0.258574 s/step
# on time step 12095 (time=60.475), 0.257044 s/step
# on time step 12111 (time=60.555), 0.256755 s/step
# on time step 12127 (time=60.635), 0.257775 s/step
# on time step 12143 (time=60.715), 0.255899 s/step
# on time step 12159 (time=60.795), 0.256842 s/step
# on time step 12175 (time=60.875), 0.255674 s/step
# on time step 12191 (time=60.955), 0.256859 s/step
# on time step 12207 (time=61.035), 0.257938 s/step
# on time step 12223 (time=61.115), 0.258283 s/step
# on time step 12239 (time=61.195), 0.258292 s/step
# on time step 12255 (time=61.275), 0.256462 s/step
# on time step 12271 (time=61.355), 0.25623 s/step
# on time step 12287 (time=61.435), 0.255661 s/step
# on time step 12303 (time=61.515), 0.255722 s/step
# on time step 12319 (time=61.595), 0.25736 s/step
# on time step 12335 (time=61.675), 0.253006 s/step
# on time step 12351 (time=61.755), 0.256857 s/step
# on time step 12367 (time=61.835), 0.255347 s/step
# on time step 12383 (time=61.915), 0.256257 s/step
# on time step 12399 (time=61.995), 0.257307 s/step
# on time step 12415 (time=62.075), 0.256213 s/step
# on time step 12431 (time=62.155), 0.257735 s/step
# on time step 12447 (time=62.235), 0.258259 s/step
# on time step 12463 (time=62.315), 0.258617 s/step
# on time step 12479 (time=62.395), 0.256416 s/step
# on time step 12495 (time=62.475), 0.257627 s/step
# on time step 12511 (time=62.555), 0.254578 s/step
# on time step 12527 (time=62.635), 0.250061 s/step
# on time step 12543 (time=62.715), 0.251581 s/step
# on time step 12559 (time=62.795), 0.251852 s/step
# on time step 12575 (time=62.875), 0.25076 s/step
# on time step 12591 (time=62.955), 0.252582 s/step
# on time step 12607 (time=63.035), 0.250015 s/step
# on time step 12623 (time=63.115), 0.2515 s/step
# on time step 12639 (time=63.195), 0.252461 s/step
# on time step 12655 (time=63.275), 0.253364 s/step
# on time step 12671 (time=63.355), 0.254141 s/step
# on time step 12687 (time=63.435), 0.252042 s/step
# on time step 12704 (time=63.52), 0.249204 s/step
# on time step 12720 (time=63.6), 0.251762 s/step
# on time step 12736 (time=63.68), 0.254019 s/step
# on time step 12752 (time=63.76), 0.251525 s/step
# on time step 12768 (time=63.84), 0.25305 s/step
# on time step 12786 (time=63.93), 0.222775 s/step
# on time step 12810 (time=64.05), 0.167564 s/step
# on time step 12847 (time=64.235), 0.110697 s/step
# on time step 12870 (time=64.35), 0.182664 s/step
# on time step 12887 (time=64.435), 0.238105 s/step
# on time step 12904 (time=64.52), 0.236043 s/step
# on time step 12921 (time=64.605), 0.237529 s/step
# on time step 12938 (time=64.69), 0.237384 s/step
# on time step 12955 (time=64.775), 0.236877 s/step
# on time step 12972 (time=64.86), 0.235483 s/step
# on time step 12989 (time=64.945), 0.236833 s/step
# on time step 13006 (time=65.03), 0.239696 s/step
# on time step 13023 (time=65.115), 0.236741 s/step
# on time step 13040 (time=65.2), 0.238917 s/step
# on time step 13057 (time=65.285), 0.238333 s/step
# on time step 13074 (time=65.37), 0.235984 s/step
# on time step 13091 (time=65.455), 0.236841 s/step
# on time step 13108 (time=65.54), 0.236407 s/step
# on time step 13125 (time=65.625), 0.240851 s/step
# on time step 13142 (time=65.71), 0.238601 s/step
# on time step 13159 (time=65.795), 0.23689 s/step
# on time step 13176 (time=65.88), 0.237848 s/step
# on time step 13193 (time=65.965), 0.238579 s/step
# on time step 13210 (time=66.05), 0.238747 s/step
# on time step 13227 (time=66.135), 0.237362 s/step
# on time step 13244 (time=66.22), 0.238628 s/step
# on time step 13261 (time=66.305), 0.2364 s/step
# on time step 13278 (time=66.39), 0.237483 s/step
# on time step 13295 (time=66.475), 0.23699 s/step
# on time step 13312 (time=66.56), 0.239509 s/step
# on time step 13329 (time=66.645), 0.237997 s/step
# on time step 13346 (time=66.73), 0.23602 s/step
# on time step 13363 (time=66.815), 0.237954 s/step
# on time step 13380 (time=66.9), 0.236833 s/step
# on time step 13397 (time=66.985), 0.236576 s/step
# on time step 13414 (time=67.07), 0.237539 s/step
# on time step 13431 (time=67.155), 0.236887 s/step
# on time step 13448 (time=67.24), 0.236131 s/step
# on time step 13466 (time=67.33), 0.234406 s/step
# on time step 13483 (time=67.415), 0.23844 s/step
# on time step 13500 (time=67.5), 0.238893 s/step
# on time step 13517 (time=67.585), 0.241735 s/step
# on time step 13534 (time=67.67), 0.239864 s/step
# on time step 13551 (time=67.755), 0.239084 s/step
# on time step 13568 (time=67.84), 0.240838 s/step
# on time step 13585 (time=67.925), 0.240271 s/step
# on time step 13606 (time=68.03), 0.191791 s/step
# on time step 13630 (time=68.15), 0.173814 s/step
# on time step 13654 (time=68.27), 0.173006 s/step
# on time step 13678 (time=68.39), 0.173534 s/step
# on time step 13701 (time=68.505), 0.173961 s/step
# on time step 13724 (time=68.62), 0.174668 s/step
# on time step 13748 (time=68.74), 0.172901 s/step
# on time step 13772 (time=68.86), 0.168328 s/step
# on time step 13796 (time=68.98), 0.168333 s/step
# on time step 13824 (time=69.12), 0.145389 s/step
# on time step 13849 (time=69.245), 0.162951 s/step
# on time step 13873 (time=69.365), 0.167234 s/step
# on time step 13898 (time=69.49), 0.165493 s/step
# on time step 13923 (time=69.615), 0.164633 s/step
# on time step 13948 (time=69.74), 0.163541 s/step
# on time step 13973 (time=69.865), 0.165718 s/step
# on time step 13998 (time=69.99), 0.164126 s/step
# on time step 14023 (time=70.115), 0.164364 s/step
# on time step 14048 (time=70.24), 0.163736 s/step
# on time step 14073 (time=70.365), 0.164673 s/step
# on time step 14098 (time=70.49), 0.164636 s/step
# on time step 14123 (time=70.615), 0.1647 s/step
# on time step 14148 (time=70.74), 0.162817 s/step
# on time step 14173 (time=70.865), 0.164366 s/step
# on time step 14198 (time=70.99), 0.164331 s/step
# on time step 14223 (time=71.115), 0.164444 s/step
# on time step 14248 (time=71.24), 0.164463 s/step
# on time step 14273 (time=71.365), 0.165524 s/step
# on time step 14298 (time=71.49), 0.165083 s/step
# on time step 14323 (time=71.615), 0.165522 s/step
# on time step 14348 (time=71.74), 0.16468 s/step
# on time step 14373 (time=71.865), 0.165501 s/step
# on time step 14400 (time=72), 0.149762 s/step
# on time step 14435 (time=72.175), 0.119496 s/step
# on time step 14453 (time=72.265), 0.229259 s/step
# on time step 14471 (time=72.355), 0.228496 s/step
# on time step 14489 (time=72.445), 0.229662 s/step
# on time step 14507 (time=72.535), 0.227704 s/step
# on time step 14525 (time=72.625), 0.22913 s/step
# on time step 14543 (time=72.715), 0.229257 s/step
# on time step 14561 (time=72.805), 0.227948 s/step
# on time step 14579 (time=72.895), 0.229579 s/step
# on time step 14597 (time=72.985), 0.229065 s/step
# on time step 14615 (time=73.075), 0.225567 s/step
# on time step 14633 (time=73.165), 0.228807 s/step
# on time step 14651 (time=73.255), 0.229547 s/step
# on time step 14669 (time=73.345), 0.229073 s/step
# on time step 14687 (time=73.435), 0.228134 s/step
# on time step 14705 (time=73.525), 0.229028 s/step
# on time step 14723 (time=73.615), 0.227808 s/step
# on time step 14741 (time=73.705), 0.229204 s/step
# on time step 14759 (time=73.795), 0.229966 s/step
# on time step 14777 (time=73.885), 0.229292 s/step
# on time step 14795 (time=73.975), 0.232776 s/step
# on time step 14813 (time=74.065), 0.228963 s/step
# on time step 14831 (time=74.155), 0.227189 s/step
# on time step 14849 (time=74.245), 0.228273 s/step
# on time step 14867 (time=74.335), 0.22791 s/step
# on time step 14885 (time=74.425), 0.232644 s/step
# on time step 14903 (time=74.515), 0.232009 s/step
# on time step 14921 (time=74.605), 0.232063 s/step
# on time step 14939 (time=74.695), 0.231264 s/step
# on time step 14957 (time=74.785), 0.232192 s/step
# on time step 14975 (time=74.875), 0.229904 s/step
# on time step 14998 (time=74.99), 0.178321 s/step
# on time step 15032 (time=75.16), 0.120928 s/step
# on time step 15059 (time=75.295), 0.153532 s/step
# on time step 15084 (time=75.42), 0.162999 s/step
# on time step 15109 (time=75.545), 0.16521 s/step
# on time step 15134 (time=75.67), 0.162778 s/step
# on time step 15159 (time=75.795), 0.162579 s/step
# on time step 15184 (time=75.92), 0.163926 s/step
# on time step 15209 (time=76.045), 0.164445 s/step
# on time step 15234 (time=76.17), 0.162309 s/step
# on time step 15259 (time=76.295), 0.162678 s/step
# on time step 15284 (time=76.42), 0.162708 s/step
# on time step 15309 (time=76.545), 0.162397 s/step
# on time step 15334 (time=76.67), 0.162417 s/step
# on time step 15359 (time=76.795), 0.162589 s/step
# on time step 15384 (time=76.92), 0.162532 s/step
# on time step 15409 (time=77.045), 0.162667 s/step
# on time step 15434 (time=77.17), 0.162963 s/step
# on time step 15459 (time=77.295), 0.162676 s/step
# on time step 15484 (time=77.42), 0.162813 s/step
# run 0 finished at t = 77.5 (15500 timesteps)

# %%
Ex_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ex,0)
Ey_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ey,0)
Ez_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_xz.npy',Ex_xz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_xz.npy',Ey_xz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_xz.npy',Ez_xz)

Ex_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ex,0)
Ey_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ey,0)
Ez_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_yz.npy',Ex_yz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_yz.npy',Ey_yz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_yz.npy',Ez_yz)

Ex01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ex,0)
Ey01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ey,0)
Ez01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_xyz1.npy',Ex01)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_xyz1.npy',Ey01)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_xyz1.npy',Ez01)

Ex00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ex,0)
Ey00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ey,0)
Ez00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_xyz0.npy',Ex00)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_xyz0.npy',Ey00)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_xyz0.npy',Ez00)
