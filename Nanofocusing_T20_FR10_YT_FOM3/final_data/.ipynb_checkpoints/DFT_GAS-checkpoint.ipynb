# %%
import meep as mp
import meep.adjoint as mpa
from meep import Animate2D
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
from meep.materials import Ag
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from PIL import Image
import matplotlib.colors as mcolors

mp.verbosity(1)
TiO2 = mp.Medium(index=2.6)
SiO2 = mp.Medium(index=1.44)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1)

# %% [markdown]
# In this example, we consider wave propagation through a simple 1d nonlinear medium with a non-zero Kerr susceptibility

# %%
os.makedirs('DFT_GAS',exist_ok=True) # Create Folder
os.makedirs('DFT_mode_volume',exist_ok=True) # Create Folder

# %% [markdown]
# 以下主要為複製在ADJOINT優化下的環境，主要是MAPPIING的函數要相同，才不會使重現結構時出現問題

# %%
resolution = 100
design_region_resolution = int(resolution)

design_region_x_width  = 1   #100 nm
design_region_y_height = 1   #100 nm
design_region_z_height = 0.02  #20 nm or 10nm

pml_size = 1.0
pml_layers = [mp.PML(pml_size,direction=mp.Z)]

Sz_size = 0.6
Sx = design_region_x_width
Sy = design_region_y_height 
Sz = 2 * pml_size + design_region_z_height + Sz_size
cell_size = mp.Vector3(Sx, Sy, Sz)

wavelengths = np.array([1.55])     # wavelengths = np.array([1.5 ,1.55, 1.6])
frequencies = np.array([1 / 1.55])

nf = 1                 #3 #wavelengths Number

minimum_length = 0.02  # minimum length scale (microns)
eta_i = 0.5            # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55           # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e      # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)

Source_distance = -0.2

fcen   = 1 / 1.55
width  = 0.2  
fwidth = width * fcen
source_center = mp.Vector3(0,0,Source_distance)  
source_size   = mp.Vector3(design_region_x_width, design_region_y_height, 0)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)]   

Nx = int(design_region_resolution * design_region_x_width) + 1
Ny = int(design_region_resolution * design_region_y_height) + 1
Nz = 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, Ag, grid_type="U_MEAN")
design_region    = mpa.DesignRegion(
            design_variables,
            volume=mp.Volume(
            center=mp.Vector3(0,0,0),
            size=mp.Vector3(design_region_x_width, design_region_y_height, design_region_z_height),
            ),
)

def mapping(x, eta, beta):
    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_x_width,
        design_region_y_height,
        design_region_resolution,
    )
    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)
    projected_field = (npa.fliplr(projected_field) + projected_field) / 2
    projected_field = (npa.flipud(projected_field) + projected_field) / 2  # left-right symmetry    
    
    return projected_field.flatten()


geometry = [mp.Block(center=design_region.center, size=design_region.size, material=design_variables)]

kpoint = mp.Vector3()
sim = mp.Simulation(
    cell_size        = cell_size,
    boundary_layers  = pml_layers,
    geometry         = geometry,
    sources          = source,
    default_material = Air,
    k_point          = kpoint,
    symmetries       = [mp.Mirror(direction=mp.X)],
    resolution       = resolution,
    extra_materials  = [Ag],       # Introducing metal complex terms
)
#---------------------------------------------------------------------------------------------------#


#-----------------[4]---------------------------------#
monitor_position   = mp.Vector3(0, 0, 0)       # Focus position
monitor_size       = mp.Vector3(0.01,0.01,design_region_z_height)     # Focus Size//////0.11
FourierFields_x    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ex,yee_grid=True)
FourierFields_y    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ey,yee_grid=True)
FourierFields_z    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list            = [FourierFields_x,FourierFields_y,FourierFields_z]


def J(fields_x,fields_y,fields_z):
    ET_x = 0
    ET_y = 0
    ET_z = 0
    ET_x_length = fields_x.shape[1]
    ET_y_length = fields_y.shape[1]
    ET_z_length = fields_z.shape[1]
    for k in range(0,ET_x_length):
        ET_x = ET_x + npa.abs(fields_x[:,k]) ** 2
    for k in range(0,ET_y_length):
        ET_y = ET_y + npa.abs(fields_y[:,k]) ** 2
    for k in range(0,ET_z_length):
        ET_z = ET_z + npa.abs(fields_z[:,k]) ** 2
    ET = ( (npa.mean(ET_x)) + (npa.mean(ET_y)) + (npa.mean(ET_z)) ) ** (1/2)  
    return ET


opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decimation_factor = 1 ,           # KEY BUG!!
    maximum_run_time=50,
)

# %% [markdown]
# 以下引入5個檔案
# evaluation_history為FOM趨勢
# beta_A,eta_A,cur_A 為mapping可能用到的參數
# x_A 為最終的結構參數

# %%
evaluation_history = np.load('Post_evaluation_history.npy')
beta_A  = np.load("Post_beta_scale_array.npy")
eta_A   = np.load("Post_eta_i_array.npy")
cur_A   = np.load("Post_cur_beta_array.npy")
x_A     = np.load("Post_x_array.npy")

# %%
plt.figure()
plt.plot(evaluation_history, "o-")

for i in range(1,13):
    plt.axvline(x=15*i, color='purple', linestyle='--', label='x=3')
plt.grid(True)
plt.xlim(0)
plt.ylim(0)
plt.xlabel("Iteration")
plt.ylabel("FOM")
# Out:
# Text(0, 0.5, 'FOM')

# %% [markdown]
# 使用 opt.update_design 函數來將sim裡的結構更新為優化完成的結構

# %%
opt.update_design([mapping(x_A, eta_A, cur_A/beta_A)])  # cur_beta/beta_scale is the final beta in the optimization.
plt.figure(figsize=(5,5))
ax = plt.gca()
opt.plot2D(
    False,
    ax=ax,
    plot_sources_flag=False,
    plot_monitors_flag=False,
    plot_boundaries_flag=False,
    output_plane = mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(design_region_x_width, design_region_y_height, 0))
)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
plt.close()
# Out:
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %%
opt.sim = mp.Simulation(
    cell_size=mp.Vector3(Sx, Sy ,Sz),
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point=kpoint,
    #symmetries=[mp.Mirror(direction=mp.X)],
    extra_materials = [Ag],
)
#src = mp.ContinuousSource(frequency=frequencies[0], fwidth=0.01 ,is_integrated=True)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)] 
opt.sim.change_sources(source)

dft_fields_xz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(Sx,0,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_yz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(0,Sy,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_xyz12 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False
                                )

dft_fields_xyz00 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False 
                                )

dft_fields_x0yz0 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(0,Sy,0),
                                yee_grid=False
                                )

dft_fields_mode_volume = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0),
                                size=mp.Vector3(Sx,Sy,0.4),
                                yee_grid=False 
                                )


#opt.sim.run(until_after_sources = 0)
opt.sim.run(until_after_sources=mp.stop_when_dft_decayed(
            tol=1e-11,
            minimum_run_time=0,
            maximum_run_time=50))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000236988 s
# Working in 3D dimensions.
# Computational cell is 1 x 1 x 2.62 with resolution 100
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 7.17579 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 2 (time=0.01), 2.21278 s/step
# on time step 9 (time=0.045), 0.578073 s/step
# on time step 18 (time=0.09), 0.480689 s/step
# on time step 27 (time=0.135), 0.467083 s/step
# on time step 36 (time=0.18), 0.474117 s/step
# on time step 43 (time=0.215), 0.6981 s/step
# on time step 49 (time=0.245), 0.680851 s/step
# on time step 55 (time=0.275), 0.668944 s/step
# on time step 62 (time=0.31), 0.67533 s/step
# on time step 68 (time=0.34), 0.67966 s/step
# on time step 75 (time=0.375), 0.655857 s/step
# on time step 82 (time=0.41), 0.64968 s/step
# on time step 88 (time=0.44), 0.702397 s/step
# on time step 95 (time=0.475), 0.653329 s/step
# on time step 102 (time=0.51), 0.657577 s/step
# on time step 109 (time=0.545), 0.654549 s/step
# on time step 116 (time=0.58), 0.668892 s/step
# on time step 122 (time=0.61), 0.67938 s/step
# on time step 129 (time=0.645), 0.655762 s/step
# on time step 136 (time=0.68), 0.648053 s/step
# on time step 143 (time=0.715), 0.644538 s/step
# on time step 150 (time=0.75), 0.627954 s/step
# on time step 159 (time=0.795), 0.477777 s/step
# on time step 166 (time=0.83), 0.641559 s/step
# on time step 173 (time=0.865), 0.636879 s/step
# on time step 180 (time=0.9), 0.637525 s/step
# on time step 187 (time=0.935), 0.615108 s/step
# on time step 194 (time=0.97), 0.628408 s/step
# on time step 201 (time=1.005), 0.636822 s/step
# on time step 208 (time=1.04), 0.622748 s/step
# on time step 215 (time=1.075), 0.607869 s/step
# on time step 222 (time=1.11), 0.60902 s/step
# on time step 229 (time=1.145), 0.622123 s/step
# on time step 236 (time=1.18), 0.614419 s/step
# on time step 243 (time=1.215), 0.628932 s/step
# on time step 250 (time=1.25), 0.61555 s/step
# on time step 257 (time=1.285), 0.61386 s/step
# on time step 264 (time=1.32), 0.619258 s/step
# on time step 271 (time=1.355), 0.614515 s/step
# on time step 278 (time=1.39), 0.602763 s/step
# on time step 285 (time=1.425), 0.612809 s/step
# on time step 292 (time=1.46), 0.622329 s/step
# on time step 299 (time=1.495), 0.621337 s/step
# on time step 306 (time=1.53), 0.620758 s/step
# on time step 313 (time=1.565), 0.617093 s/step
# on time step 320 (time=1.6), 0.639851 s/step
# on time step 326 (time=1.63), 0.679465 s/step
# on time step 333 (time=1.665), 0.626945 s/step
# on time step 340 (time=1.7), 0.63712 s/step
# on time step 347 (time=1.735), 0.599617 s/step
# on time step 354 (time=1.77), 0.590552 s/step
# on time step 361 (time=1.805), 0.625222 s/step
# on time step 368 (time=1.84), 0.610864 s/step
# on time step 375 (time=1.875), 0.597529 s/step
# on time step 387 (time=1.935), 0.363196 s/step
# on time step 394 (time=1.97), 0.587995 s/step
# on time step 401 (time=2.005), 0.579959 s/step
# on time step 408 (time=2.04), 0.592475 s/step
# on time step 415 (time=2.075), 0.593868 s/step
# on time step 422 (time=2.11), 0.581002 s/step
# on time step 429 (time=2.145), 0.584462 s/step
# on time step 436 (time=2.18), 0.586147 s/step
# on time step 443 (time=2.215), 0.578401 s/step
# on time step 450 (time=2.25), 0.5857 s/step
# on time step 457 (time=2.285), 0.579984 s/step
# on time step 464 (time=2.32), 0.578225 s/step
# on time step 471 (time=2.355), 0.588406 s/step
# on time step 478 (time=2.39), 0.602408 s/step
# on time step 485 (time=2.425), 0.58289 s/step
# on time step 492 (time=2.46), 0.577413 s/step
# on time step 499 (time=2.495), 0.589536 s/step
# on time step 506 (time=2.53), 0.585418 s/step
# on time step 513 (time=2.565), 0.574928 s/step
# on time step 521 (time=2.605), 0.560463 s/step
# on time step 528 (time=2.64), 0.590195 s/step
# on time step 536 (time=2.68), 0.557341 s/step
# on time step 544 (time=2.72), 0.557369 s/step
# on time step 552 (time=2.76), 0.568557 s/step
# on time step 559 (time=2.795), 0.599204 s/step
# on time step 566 (time=2.83), 0.585603 s/step
# on time step 573 (time=2.865), 0.587737 s/step
# on time step 580 (time=2.9), 0.57845 s/step
# on time step 587 (time=2.935), 0.584007 s/step
# on time step 594 (time=2.97), 0.580856 s/step
# on time step 601 (time=3.005), 0.576577 s/step
# on time step 608 (time=3.04), 0.588131 s/step
# on time step 615 (time=3.075), 0.577503 s/step
# on time step 622 (time=3.11), 0.590034 s/step
# on time step 629 (time=3.145), 0.579397 s/step
# on time step 636 (time=3.18), 0.592603 s/step
# on time step 643 (time=3.215), 0.584359 s/step
# on time step 650 (time=3.25), 0.576403 s/step
# on time step 657 (time=3.285), 0.581466 s/step
# on time step 664 (time=3.32), 0.576508 s/step
# on time step 671 (time=3.355), 0.575978 s/step
# on time step 678 (time=3.39), 0.584467 s/step
# on time step 685 (time=3.425), 0.578754 s/step
# on time step 692 (time=3.46), 0.576629 s/step
# on time step 699 (time=3.495), 0.579385 s/step
# on time step 706 (time=3.53), 0.588428 s/step
# on time step 717 (time=3.585), 0.390993 s/step
# on time step 727 (time=3.635), 0.431658 s/step
# on time step 736 (time=3.68), 0.450742 s/step
# on time step 743 (time=3.715), 0.66601 s/step
# on time step 750 (time=3.75), 0.667554 s/step
# on time step 756 (time=3.78), 0.706081 s/step
# on time step 762 (time=3.81), 0.708146 s/step
# on time step 769 (time=3.845), 0.666579 s/step
# on time step 776 (time=3.88), 0.669339 s/step
# on time step 782 (time=3.91), 0.706259 s/step
# on time step 788 (time=3.94), 0.684833 s/step
# on time step 794 (time=3.97), 0.672975 s/step
# on time step 800 (time=4), 0.677866 s/step
# on time step 806 (time=4.03), 0.675207 s/step
# on time step 812 (time=4.06), 0.68669 s/step
# on time step 818 (time=4.09), 0.68629 s/step
# on time step 824 (time=4.12), 0.690523 s/step
# on time step 830 (time=4.15), 0.677565 s/step
# on time step 836 (time=4.18), 0.683474 s/step
# on time step 842 (time=4.21), 0.678713 s/step
# on time step 849 (time=4.245), 0.643335 s/step
# on time step 858 (time=4.29), 0.455111 s/step
# on time step 867 (time=4.335), 0.486565 s/step
# on time step 876 (time=4.38), 0.473065 s/step
# on time step 885 (time=4.425), 0.466789 s/step
# on time step 894 (time=4.47), 0.464513 s/step
# on time step 903 (time=4.515), 0.493611 s/step
# on time step 912 (time=4.56), 0.466792 s/step
# on time step 921 (time=4.605), 0.471515 s/step
# on time step 930 (time=4.65), 0.483218 s/step
# on time step 939 (time=4.695), 0.470204 s/step
# on time step 948 (time=4.74), 0.465026 s/step
# on time step 957 (time=4.785), 0.469696 s/step
# on time step 966 (time=4.83), 0.464392 s/step
# on time step 975 (time=4.875), 0.481335 s/step
# on time step 984 (time=4.92), 0.472759 s/step
# on time step 993 (time=4.965), 0.473441 s/step
# on time step 1002 (time=5.01), 0.464009 s/step
# on time step 1009 (time=5.045), 0.601967 s/step
# on time step 1016 (time=5.08), 0.625727 s/step
# on time step 1023 (time=5.115), 0.628548 s/step
# on time step 1030 (time=5.15), 0.624325 s/step
# on time step 1037 (time=5.185), 0.625114 s/step
# on time step 1044 (time=5.22), 0.631381 s/step
# on time step 1051 (time=5.255), 0.611132 s/step
# on time step 1060 (time=5.3), 0.471127 s/step
# on time step 1069 (time=5.345), 0.463398 s/step
# on time step 1078 (time=5.39), 0.470789 s/step
# on time step 1087 (time=5.435), 0.467173 s/step
# on time step 1096 (time=5.48), 0.462287 s/step
# on time step 1104 (time=5.52), 0.526386 s/step
# on time step 1111 (time=5.555), 0.630564 s/step
# on time step 1119 (time=5.595), 0.528558 s/step
# on time step 1129 (time=5.645), 0.432722 s/step
# on time step 1140 (time=5.7), 0.3835 s/step
# on time step 1149 (time=5.745), 0.487132 s/step
# on time step 1155 (time=5.775), 0.698643 s/step
# on time step 1161 (time=5.805), 0.669794 s/step
# on time step 1168 (time=5.84), 0.614051 s/step
# on time step 1175 (time=5.875), 0.589759 s/step
# on time step 1182 (time=5.91), 0.586184 s/step
# on time step 1189 (time=5.945), 0.598311 s/step
# on time step 1196 (time=5.98), 0.59897 s/step
# on time step 1203 (time=6.015), 0.578415 s/step
# on time step 1210 (time=6.05), 0.58412 s/step
# on time step 1217 (time=6.085), 0.579983 s/step
# on time step 1224 (time=6.12), 0.594817 s/step
# on time step 1231 (time=6.155), 0.619814 s/step
# on time step 1238 (time=6.19), 0.612668 s/step
# on time step 1245 (time=6.225), 0.61161 s/step
# on time step 1252 (time=6.26), 0.600055 s/step
# on time step 1259 (time=6.295), 0.601901 s/step
# on time step 1266 (time=6.33), 0.596888 s/step
# on time step 1273 (time=6.365), 0.608157 s/step
# on time step 1280 (time=6.4), 0.607034 s/step
# on time step 1287 (time=6.435), 0.60133 s/step
# on time step 1294 (time=6.47), 0.606022 s/step
# on time step 1301 (time=6.505), 0.613035 s/step
# on time step 1308 (time=6.54), 0.606985 s/step
# on time step 1315 (time=6.575), 0.614997 s/step
# on time step 1322 (time=6.61), 0.610176 s/step
# on time step 1329 (time=6.645), 0.61225 s/step
# on time step 1336 (time=6.68), 0.610169 s/step
# on time step 1343 (time=6.715), 0.604435 s/step
# on time step 1350 (time=6.75), 0.608681 s/step
# on time step 1357 (time=6.785), 0.606889 s/step
# on time step 1364 (time=6.82), 0.605018 s/step
# on time step 1371 (time=6.855), 0.59673 s/step
# on time step 1378 (time=6.89), 0.602583 s/step
# on time step 1385 (time=6.925), 0.59199 s/step
# on time step 1392 (time=6.96), 0.601659 s/step
# on time step 1399 (time=6.995), 0.591979 s/step
# on time step 1406 (time=7.03), 0.600424 s/step
# on time step 1413 (time=7.065), 0.603147 s/step
# on time step 1420 (time=7.1), 0.613807 s/step
# on time step 1427 (time=7.135), 0.604154 s/step
# on time step 1434 (time=7.17), 0.598955 s/step
# on time step 1441 (time=7.205), 0.604925 s/step
# on time step 1448 (time=7.24), 0.608944 s/step
# on time step 1455 (time=7.275), 0.602695 s/step
# on time step 1462 (time=7.31), 0.616814 s/step
# on time step 1469 (time=7.345), 0.615627 s/step
# on time step 1476 (time=7.38), 0.604023 s/step
# on time step 1483 (time=7.415), 0.609181 s/step
# on time step 1492 (time=7.46), 0.473209 s/step
# on time step 1503 (time=7.515), 0.36996 s/step
# on time step 1519 (time=7.595), 0.252584 s/step
# on time step 1529 (time=7.645), 0.429593 s/step
# on time step 1538 (time=7.69), 0.475186 s/step
# on time step 1547 (time=7.735), 0.470157 s/step
# on time step 1556 (time=7.78), 0.462795 s/step
# on time step 1565 (time=7.825), 0.461083 s/step
# on time step 1572 (time=7.86), 0.591357 s/step
# on time step 1579 (time=7.895), 0.594329 s/step
# on time step 1586 (time=7.93), 0.597564 s/step
# on time step 1593 (time=7.965), 0.592075 s/step
# on time step 1600 (time=8), 0.596974 s/step
# on time step 1606 (time=8.03), 0.695826 s/step
# on time step 1612 (time=8.06), 0.717131 s/step
# on time step 1618 (time=8.09), 0.714074 s/step
# on time step 1624 (time=8.12), 0.708912 s/step
# on time step 1630 (time=8.15), 0.758667 s/step
# on time step 1636 (time=8.18), 0.71629 s/step
# on time step 1642 (time=8.21), 0.728229 s/step
# on time step 1648 (time=8.24), 0.720221 s/step
# on time step 1654 (time=8.27), 0.716288 s/step
# on time step 1660 (time=8.3), 0.717125 s/step
# on time step 1665 (time=8.325), 0.906317 s/step
# on time step 1672 (time=8.36), 0.623792 s/step
# on time step 1679 (time=8.395), 0.627132 s/step
# on time step 1686 (time=8.43), 0.620567 s/step
# on time step 1693 (time=8.465), 0.622143 s/step
# on time step 1701 (time=8.505), 0.518374 s/step
# on time step 1707 (time=8.535), 0.705118 s/step
# on time step 1713 (time=8.565), 0.760159 s/step
# on time step 1720 (time=8.6), 0.636962 s/step
# on time step 1726 (time=8.63), 0.674493 s/step
# on time step 1733 (time=8.665), 0.582341 s/step
# on time step 1740 (time=8.7), 0.589294 s/step
# on time step 1747 (time=8.735), 0.584826 s/step
# on time step 1754 (time=8.77), 0.604064 s/step
# on time step 1761 (time=8.805), 0.608372 s/step
# on time step 1768 (time=8.84), 0.589745 s/step
# on time step 1775 (time=8.875), 0.609535 s/step
# on time step 1782 (time=8.91), 0.617231 s/step
# on time step 1789 (time=8.945), 0.608057 s/step
# on time step 1796 (time=8.98), 0.610917 s/step
# on time step 1803 (time=9.015), 0.632356 s/step
# on time step 1810 (time=9.05), 0.620398 s/step
# on time step 1817 (time=9.085), 0.622573 s/step
# on time step 1824 (time=9.12), 0.613116 s/step
# on time step 1832 (time=9.16), 0.547599 s/step
# on time step 1840 (time=9.2), 0.51934 s/step
# on time step 1847 (time=9.235), 0.573692 s/step
# on time step 1855 (time=9.275), 0.577704 s/step
# on time step 1862 (time=9.31), 0.670185 s/step
# on time step 1868 (time=9.34), 0.699944 s/step
# on time step 1874 (time=9.37), 0.670029 s/step
# on time step 1881 (time=9.405), 0.663771 s/step
# on time step 1887 (time=9.435), 0.714135 s/step
# on time step 1893 (time=9.465), 0.669664 s/step
# on time step 1900 (time=9.5), 0.664961 s/step
# on time step 1906 (time=9.53), 0.695606 s/step
# on time step 1912 (time=9.56), 0.671417 s/step
# on time step 1919 (time=9.595), 0.666047 s/step
# on time step 1925 (time=9.625), 0.669215 s/step
# on time step 1931 (time=9.655), 0.668702 s/step
# on time step 1937 (time=9.685), 0.681397 s/step
# on time step 1943 (time=9.715), 0.684322 s/step
# on time step 1949 (time=9.745), 0.679669 s/step
# on time step 1955 (time=9.775), 0.671984 s/step
# on time step 1961 (time=9.805), 0.666978 s/step
# on time step 1967 (time=9.835), 0.670772 s/step
# on time step 1974 (time=9.87), 0.608182 s/step
# on time step 1983 (time=9.915), 0.448892 s/step
# on time step 1992 (time=9.96), 0.460127 s/step
# on time step 1999 (time=9.995), 0.633214 s/step
# on time step 2006 (time=10.03), 0.588847 s/step
# on time step 2013 (time=10.065), 0.587887 s/step
# on time step 2020 (time=10.1), 0.585261 s/step
# on time step 2027 (time=10.135), 0.576823 s/step
# on time step 2035 (time=10.175), 0.548547 s/step
# on time step 2043 (time=10.215), 0.539034 s/step
# on time step 2053 (time=10.265), 0.44056 s/step
# on time step 2062 (time=10.31), 0.468903 s/step
# on time step 2071 (time=10.355), 0.456183 s/step
# on time step 2080 (time=10.4), 0.453881 s/step
# on time step 2090 (time=10.45), 0.440135 s/step
# on time step 2100 (time=10.5), 0.439699 s/step
# on time step 2109 (time=10.545), 0.453035 s/step
# on time step 2118 (time=10.59), 0.45515 s/step
# on time step 2128 (time=10.64), 0.437054 s/step
# on time step 2138 (time=10.69), 0.436084 s/step
# on time step 2147 (time=10.735), 0.44747 s/step
# on time step 2156 (time=10.78), 0.451985 s/step
# on time step 2165 (time=10.825), 0.446241 s/step
# on time step 2174 (time=10.87), 0.466599 s/step
# on time step 2183 (time=10.915), 0.455656 s/step
# on time step 2192 (time=10.96), 0.48878 s/step
# on time step 2199 (time=10.995), 0.62898 s/step
# on time step 2206 (time=11.03), 0.623712 s/step
# on time step 2213 (time=11.065), 0.619488 s/step
# on time step 2220 (time=11.1), 0.622836 s/step
# on time step 2227 (time=11.135), 0.620437 s/step
# on time step 2234 (time=11.17), 0.630474 s/step
# on time step 2241 (time=11.205), 0.628726 s/step
# on time step 2248 (time=11.24), 0.617567 s/step
# on time step 2255 (time=11.275), 0.626766 s/step
# on time step 2262 (time=11.31), 0.631745 s/step
# on time step 2269 (time=11.345), 0.627053 s/step
# on time step 2276 (time=11.38), 0.626594 s/step
# on time step 2283 (time=11.415), 0.639528 s/step
# on time step 2290 (time=11.45), 0.630434 s/step
# on time step 2297 (time=11.485), 0.629095 s/step
# on time step 2304 (time=11.52), 0.624151 s/step
# on time step 2311 (time=11.555), 0.640642 s/step
# on time step 2318 (time=11.59), 0.631525 s/step
# on time step 2325 (time=11.625), 0.627582 s/step
# on time step 2334 (time=11.67), 0.47426 s/step
# on time step 2344 (time=11.72), 0.423357 s/step
# on time step 2354 (time=11.77), 0.421782 s/step
# on time step 2364 (time=11.82), 0.418401 s/step
# on time step 2374 (time=11.87), 0.417114 s/step
# on time step 2384 (time=11.92), 0.411801 s/step
# on time step 2394 (time=11.97), 0.432447 s/step
# on time step 2402 (time=12.01), 0.575165 s/step
# on time step 2408 (time=12.04), 0.668261 s/step
# on time step 2415 (time=12.075), 0.66827 s/step
# on time step 2422 (time=12.11), 0.631003 s/step
# on time step 2429 (time=12.145), 0.599926 s/step
# on time step 2444 (time=12.22), 0.293292 s/step
# on time step 2454 (time=12.27), 0.406334 s/step
# on time step 2463 (time=12.315), 0.446114 s/step
# on time step 2472 (time=12.36), 0.474215 s/step
# on time step 2481 (time=12.405), 0.457144 s/step
# on time step 2491 (time=12.455), 0.438021 s/step
# on time step 2500 (time=12.5), 0.466804 s/step
# on time step 2510 (time=12.55), 0.438322 s/step
# on time step 2520 (time=12.6), 0.440224 s/step
# on time step 2530 (time=12.65), 0.445503 s/step
# on time step 2539 (time=12.695), 0.456722 s/step
# on time step 2549 (time=12.745), 0.439086 s/step
# on time step 2559 (time=12.795), 0.437882 s/step
# on time step 2566 (time=12.83), 0.574596 s/step
# on time step 2573 (time=12.865), 0.583305 s/step
# on time step 2580 (time=12.9), 0.587665 s/step
# on time step 2587 (time=12.935), 0.573499 s/step
# on time step 2595 (time=12.975), 0.56957 s/step
# on time step 2603 (time=13.015), 0.567359 s/step
# on time step 2611 (time=13.055), 0.570186 s/step
# on time step 2618 (time=13.09), 0.572884 s/step
# on time step 2625 (time=13.125), 0.573593 s/step
# on time step 2632 (time=13.16), 0.580222 s/step
# on time step 2640 (time=13.2), 0.567329 s/step
# on time step 2647 (time=13.235), 0.580403 s/step
# on time step 2654 (time=13.27), 0.574268 s/step
# on time step 2661 (time=13.305), 0.573191 s/step
# on time step 2669 (time=13.345), 0.568349 s/step
# on time step 2677 (time=13.385), 0.570544 s/step
# on time step 2685 (time=13.425), 0.570957 s/step
# on time step 2693 (time=13.465), 0.568511 s/step
# on time step 2700 (time=13.5), 0.573471 s/step
# on time step 2707 (time=13.535), 0.57228 s/step
# on time step 2715 (time=13.575), 0.570446 s/step
# on time step 2722 (time=13.61), 0.57835 s/step
# on time step 2730 (time=13.65), 0.571232 s/step
# on time step 2738 (time=13.69), 0.571607 s/step
# on time step 2745 (time=13.725), 0.576225 s/step
# on time step 2752 (time=13.76), 0.576216 s/step
# on time step 2759 (time=13.795), 0.577979 s/step
# on time step 2767 (time=13.835), 0.571126 s/step
# on time step 2775 (time=13.875), 0.570418 s/step
# on time step 2782 (time=13.91), 0.573522 s/step
# on time step 2790 (time=13.95), 0.568432 s/step
# on time step 2797 (time=13.985), 0.571758 s/step
# on time step 2805 (time=14.025), 0.567422 s/step
# on time step 2813 (time=14.065), 0.56006 s/step
# on time step 2821 (time=14.105), 0.558128 s/step
# on time step 2829 (time=14.145), 0.556139 s/step
# on time step 2837 (time=14.185), 0.555254 s/step
# on time step 2845 (time=14.225), 0.547325 s/step
# on time step 2855 (time=14.275), 0.419316 s/step
# on time step 2866 (time=14.33), 0.387492 s/step
# on time step 2876 (time=14.38), 0.432299 s/step
# on time step 2886 (time=14.43), 0.428726 s/step
# on time step 2896 (time=14.48), 0.436929 s/step
# on time step 2906 (time=14.53), 0.428217 s/step
# on time step 2916 (time=14.58), 0.436039 s/step
# on time step 2926 (time=14.63), 0.434247 s/step
# on time step 2936 (time=14.68), 0.437582 s/step
# on time step 2946 (time=14.73), 0.443151 s/step
# on time step 2956 (time=14.78), 0.435241 s/step
# on time step 2966 (time=14.83), 0.439262 s/step
# on time step 2976 (time=14.88), 0.4368 s/step
# on time step 2985 (time=14.925), 0.444787 s/step
# on time step 2995 (time=14.975), 0.4366 s/step
# on time step 3005 (time=15.025), 0.436111 s/step
# on time step 3015 (time=15.075), 0.437392 s/step
# on time step 3025 (time=15.125), 0.438133 s/step
# on time step 3035 (time=15.175), 0.437487 s/step
# on time step 3045 (time=15.225), 0.433612 s/step
# on time step 3055 (time=15.275), 0.435104 s/step
# on time step 3065 (time=15.325), 0.43444 s/step
# on time step 3075 (time=15.375), 0.433432 s/step
# on time step 3085 (time=15.425), 0.439595 s/step
# on time step 3095 (time=15.475), 0.438047 s/step
# on time step 3105 (time=15.525), 0.437883 s/step
# on time step 3114 (time=15.57), 0.450428 s/step
# on time step 3124 (time=15.62), 0.440082 s/step
# on time step 3134 (time=15.67), 0.43339 s/step
# on time step 3144 (time=15.72), 0.443351 s/step
# on time step 3153 (time=15.765), 0.445303 s/step
# on time step 3161 (time=15.805), 0.557198 s/step
# on time step 3169 (time=15.845), 0.55936 s/step
# on time step 3177 (time=15.885), 0.559611 s/step
# on time step 3185 (time=15.925), 0.56238 s/step
# on time step 3192 (time=15.96), 0.578361 s/step
# on time step 3199 (time=15.995), 0.587215 s/step
# on time step 3206 (time=16.03), 0.596351 s/step
# on time step 3213 (time=16.065), 0.581917 s/step
# on time step 3220 (time=16.1), 0.596983 s/step
# on time step 3227 (time=16.135), 0.579647 s/step
# on time step 3234 (time=16.17), 0.600865 s/step
# on time step 3241 (time=16.205), 0.600618 s/step
# on time step 3248 (time=16.24), 0.584654 s/step
# on time step 3255 (time=16.275), 0.597664 s/step
# on time step 3262 (time=16.31), 0.596927 s/step
# on time step 3269 (time=16.345), 0.599435 s/step
# on time step 3276 (time=16.38), 0.585233 s/step
# on time step 3283 (time=16.415), 0.589068 s/step
# on time step 3290 (time=16.45), 0.585656 s/step
# on time step 3297 (time=16.485), 0.598796 s/step
# on time step 3304 (time=16.52), 0.604242 s/step
# on time step 3313 (time=16.565), 0.447366 s/step
# on time step 3324 (time=16.62), 0.371512 s/step
# on time step 3339 (time=16.695), 0.280916 s/step
# on time step 3349 (time=16.745), 0.416242 s/step
# on time step 3359 (time=16.795), 0.430098 s/step
# on time step 3369 (time=16.845), 0.428969 s/step
# on time step 3379 (time=16.895), 0.428924 s/step
# on time step 3389 (time=16.945), 0.429864 s/step
# on time step 3399 (time=16.995), 0.430986 s/step
# on time step 3409 (time=17.045), 0.436961 s/step
# on time step 3419 (time=17.095), 0.431006 s/step
# on time step 3429 (time=17.145), 0.428782 s/step
# on time step 3439 (time=17.195), 0.427208 s/step
# on time step 3449 (time=17.245), 0.43352 s/step
# on time step 3459 (time=17.295), 0.426265 s/step
# on time step 3469 (time=17.345), 0.428482 s/step
# on time step 3479 (time=17.395), 0.427248 s/step
# on time step 3489 (time=17.445), 0.430607 s/step
# on time step 3499 (time=17.495), 0.433581 s/step
# on time step 3509 (time=17.545), 0.431099 s/step
# on time step 3519 (time=17.595), 0.43633 s/step
# on time step 3529 (time=17.645), 0.432395 s/step
# on time step 3539 (time=17.695), 0.427316 s/step
# on time step 3549 (time=17.745), 0.433693 s/step
# on time step 3561 (time=17.805), 0.349845 s/step
# on time step 3571 (time=17.855), 0.436263 s/step
# on time step 3580 (time=17.9), 0.451128 s/step
# on time step 3589 (time=17.945), 0.444647 s/step
# on time step 3598 (time=17.99), 0.461483 s/step
# on time step 3607 (time=18.035), 0.455643 s/step
# on time step 3616 (time=18.08), 0.45269 s/step
# on time step 3625 (time=18.125), 0.444709 s/step
# on time step 3634 (time=18.17), 0.450749 s/step
# on time step 3643 (time=18.215), 0.445986 s/step
# on time step 3652 (time=18.26), 0.446934 s/step
# on time step 3661 (time=18.305), 0.461129 s/step
# on time step 3670 (time=18.35), 0.448283 s/step
# on time step 3679 (time=18.395), 0.449997 s/step
# on time step 3688 (time=18.44), 0.45256 s/step
# on time step 3697 (time=18.485), 0.448051 s/step
# on time step 3707 (time=18.535), 0.444574 s/step
# on time step 3717 (time=18.585), 0.445605 s/step
# on time step 3726 (time=18.63), 0.45187 s/step
# on time step 3735 (time=18.675), 0.447669 s/step
# on time step 3744 (time=18.72), 0.445008 s/step
# on time step 3754 (time=18.77), 0.443641 s/step
# on time step 3764 (time=18.82), 0.443377 s/step
# on time step 3774 (time=18.87), 0.440904 s/step
# on time step 3783 (time=18.915), 0.454259 s/step
# on time step 3793 (time=18.965), 0.444818 s/step
# on time step 3803 (time=19.015), 0.442112 s/step
# on time step 3813 (time=19.065), 0.443235 s/step
# on time step 3823 (time=19.115), 0.443592 s/step
# on time step 3833 (time=19.165), 0.442247 s/step
# on time step 3843 (time=19.215), 0.43493 s/step
# on time step 3853 (time=19.265), 0.422649 s/step
# on time step 3862 (time=19.31), 0.512157 s/step
# on time step 3869 (time=19.345), 0.599052 s/step
# on time step 3876 (time=19.38), 0.600134 s/step
# on time step 3883 (time=19.415), 0.604108 s/step
# on time step 3890 (time=19.45), 0.601691 s/step
# on time step 3897 (time=19.485), 0.602963 s/step
# on time step 3904 (time=19.52), 0.589982 s/step
# on time step 3911 (time=19.555), 0.609308 s/step
# on time step 3918 (time=19.59), 0.599146 s/step
# on time step 3925 (time=19.625), 0.602617 s/step
# on time step 3932 (time=19.66), 0.597874 s/step
# on time step 3939 (time=19.695), 0.602982 s/step
# on time step 3946 (time=19.73), 0.596908 s/step
# on time step 3953 (time=19.765), 0.594403 s/step
# on time step 3960 (time=19.8), 0.600957 s/step
# on time step 3967 (time=19.835), 0.60062 s/step
# on time step 3974 (time=19.87), 0.596509 s/step
# on time step 3981 (time=19.905), 0.601492 s/step
# on time step 3987 (time=19.935), 0.678308 s/step
# on time step 3993 (time=19.965), 0.738966 s/step
# on time step 4000 (time=20), 0.643983 s/step
# on time step 4009 (time=20.045), 0.458224 s/step
# on time step 4020 (time=20.1), 0.37393 s/step
# on time step 4029 (time=20.145), 0.477142 s/step
# on time step 4039 (time=20.195), 0.446969 s/step
# on time step 4049 (time=20.245), 0.438555 s/step
# on time step 4059 (time=20.295), 0.440802 s/step
# on time step 4068 (time=20.34), 0.448981 s/step
# on time step 4078 (time=20.39), 0.44268 s/step
# on time step 4087 (time=20.435), 0.446034 s/step
# on time step 4097 (time=20.485), 0.437263 s/step
# on time step 4107 (time=20.535), 0.441733 s/step
# on time step 4117 (time=20.585), 0.440958 s/step
# on time step 4126 (time=20.63), 0.449665 s/step
# on time step 4135 (time=20.675), 0.460249 s/step
# on time step 4145 (time=20.725), 0.441302 s/step
# on time step 4155 (time=20.775), 0.439044 s/step
# on time step 4165 (time=20.825), 0.438057 s/step
# on time step 4175 (time=20.875), 0.441123 s/step
# on time step 4185 (time=20.925), 0.437547 s/step
# on time step 4195 (time=20.975), 0.443084 s/step
# on time step 4205 (time=21.025), 0.434171 s/step
# on time step 4214 (time=21.07), 0.458617 s/step
# on time step 4223 (time=21.115), 0.447169 s/step
# on time step 4232 (time=21.16), 0.450295 s/step
# on time step 4242 (time=21.21), 0.433096 s/step
# on time step 4252 (time=21.26), 0.436629 s/step
# on time step 4261 (time=21.305), 0.447416 s/step
# on time step 4270 (time=21.35), 0.447088 s/step
# on time step 4280 (time=21.4), 0.447644 s/step
# on time step 4290 (time=21.45), 0.440922 s/step
# on time step 4300 (time=21.5), 0.443222 s/step
# on time step 4310 (time=21.55), 0.438958 s/step
# on time step 4320 (time=21.6), 0.441582 s/step
# on time step 4330 (time=21.65), 0.434696 s/step
# on time step 4340 (time=21.7), 0.435776 s/step
# on time step 4350 (time=21.75), 0.437992 s/step
# on time step 4360 (time=21.8), 0.433498 s/step
# on time step 4370 (time=21.85), 0.440881 s/step
# on time step 4379 (time=21.895), 0.452216 s/step
# on time step 4389 (time=21.945), 0.439539 s/step
# on time step 4399 (time=21.995), 0.438202 s/step
# on time step 4409 (time=22.045), 0.440545 s/step
# on time step 4419 (time=22.095), 0.442496 s/step
# on time step 4428 (time=22.14), 0.450744 s/step
# on time step 4437 (time=22.185), 0.449957 s/step
# on time step 4447 (time=22.235), 0.438446 s/step
# on time step 4457 (time=22.285), 0.446217 s/step
# on time step 4467 (time=22.335), 0.442111 s/step
# on time step 4476 (time=22.38), 0.448201 s/step
# on time step 4485 (time=22.425), 0.450453 s/step
# on time step 4494 (time=22.47), 0.448552 s/step
# on time step 4504 (time=22.52), 0.443394 s/step
# on time step 4514 (time=22.57), 0.442478 s/step
# on time step 4524 (time=22.62), 0.442873 s/step
# on time step 4534 (time=22.67), 0.414216 s/step
# on time step 4542 (time=22.71), 0.522211 s/step
# on time step 4549 (time=22.745), 0.60145 s/step
# on time step 4555 (time=22.775), 0.671093 s/step
# on time step 4562 (time=22.81), 0.625685 s/step
# on time step 4569 (time=22.845), 0.627419 s/step
# on time step 4576 (time=22.88), 0.625106 s/step
# on time step 4583 (time=22.915), 0.635977 s/step
# on time step 4589 (time=22.945), 0.672759 s/step
# on time step 4596 (time=22.98), 0.643591 s/step
# on time step 4603 (time=23.015), 0.62869 s/step
# on time step 4610 (time=23.05), 0.633059 s/step
# on time step 4617 (time=23.085), 0.630994 s/step
# on time step 4623 (time=23.115), 0.666933 s/step
# on time step 4630 (time=23.15), 0.633992 s/step
# on time step 4637 (time=23.185), 0.635513 s/step
# on time step 4644 (time=23.22), 0.631415 s/step
# on time step 4651 (time=23.255), 0.6318 s/step
# on time step 4658 (time=23.29), 0.658683 s/step
# on time step 4665 (time=23.325), 0.646633 s/step
# on time step 4672 (time=23.36), 0.631142 s/step
# on time step 4679 (time=23.395), 0.62552 s/step
# on time step 4686 (time=23.43), 0.631387 s/step
# on time step 4693 (time=23.465), 0.634826 s/step
# on time step 4700 (time=23.5), 0.630891 s/step
# on time step 4707 (time=23.535), 0.646134 s/step
# on time step 4714 (time=23.57), 0.649305 s/step
# on time step 4721 (time=23.605), 0.640137 s/step
# on time step 4728 (time=23.64), 0.644026 s/step
# on time step 4735 (time=23.675), 0.632512 s/step
# on time step 4742 (time=23.71), 0.635524 s/step
# on time step 4749 (time=23.745), 0.661413 s/step
# on time step 4755 (time=23.775), 0.673336 s/step
# on time step 4761 (time=23.805), 0.677675 s/step
# on time step 4767 (time=23.835), 0.668468 s/step
# on time step 4773 (time=23.865), 0.67348 s/step
# on time step 4779 (time=23.895), 0.672154 s/step
# on time step 4785 (time=23.925), 0.677655 s/step
# on time step 4791 (time=23.955), 0.690982 s/step
# on time step 4797 (time=23.985), 0.689552 s/step
# on time step 4803 (time=24.015), 0.69328 s/step
# on time step 4809 (time=24.045), 0.690553 s/step
# on time step 4815 (time=24.075), 0.690189 s/step
# on time step 4821 (time=24.105), 0.673401 s/step
# on time step 4827 (time=24.135), 0.674573 s/step
# on time step 4833 (time=24.165), 0.672676 s/step
# on time step 4839 (time=24.195), 0.681321 s/step
# on time step 4845 (time=24.225), 0.671966 s/step
# on time step 4852 (time=24.26), 0.612733 s/step
# on time step 4864 (time=24.32), 0.341098 s/step
# on time step 4872 (time=24.36), 0.527746 s/step
# on time step 4882 (time=24.41), 0.428113 s/step
# on time step 4890 (time=24.45), 0.549511 s/step
# on time step 4899 (time=24.495), 0.452107 s/step
# on time step 4909 (time=24.545), 0.424217 s/step
# on time step 4919 (time=24.595), 0.433744 s/step
# on time step 4929 (time=24.645), 0.427068 s/step
# on time step 4939 (time=24.695), 0.426446 s/step
# on time step 4948 (time=24.74), 0.447568 s/step
# on time step 4958 (time=24.79), 0.42219 s/step
# on time step 4968 (time=24.84), 0.424025 s/step
# on time step 4978 (time=24.89), 0.427314 s/step
# on time step 4987 (time=24.935), 0.449794 s/step
# on time step 4997 (time=24.985), 0.426422 s/step
# on time step 5006 (time=25.03), 0.450414 s/step
# on time step 5014 (time=25.07), 0.551603 s/step
# on time step 5022 (time=25.11), 0.556106 s/step
# on time step 5029 (time=25.145), 0.581668 s/step
# on time step 5037 (time=25.185), 0.564372 s/step
# on time step 5045 (time=25.225), 0.553479 s/step
# on time step 5053 (time=25.265), 0.558871 s/step
# on time step 5061 (time=25.305), 0.551949 s/step
# on time step 5069 (time=25.345), 0.551375 s/step
# on time step 5077 (time=25.385), 0.554001 s/step
# on time step 5085 (time=25.425), 0.569696 s/step
# on time step 5093 (time=25.465), 0.559609 s/step
# on time step 5101 (time=25.505), 0.569688 s/step
# on time step 5109 (time=25.545), 0.55612 s/step
# on time step 5117 (time=25.585), 0.558784 s/step
# on time step 5125 (time=25.625), 0.551808 s/step
# on time step 5133 (time=25.665), 0.552899 s/step
# on time step 5141 (time=25.705), 0.555395 s/step
# on time step 5149 (time=25.745), 0.551139 s/step
# on time step 5157 (time=25.785), 0.553214 s/step
# on time step 5164 (time=25.82), 0.584826 s/step
# on time step 5171 (time=25.855), 0.598813 s/step
# on time step 5178 (time=25.89), 0.590258 s/step
# on time step 5185 (time=25.925), 0.599385 s/step
# on time step 5192 (time=25.96), 0.603334 s/step
# on time step 5199 (time=25.995), 0.596326 s/step
# on time step 5206 (time=26.03), 0.60054 s/step
# on time step 5214 (time=26.07), 0.551114 s/step
# on time step 5222 (time=26.11), 0.527264 s/step
# on time step 5230 (time=26.15), 0.524447 s/step
# on time step 5238 (time=26.19), 0.521712 s/step
# on time step 5246 (time=26.23), 0.526408 s/step
# on time step 5254 (time=26.27), 0.521906 s/step
# on time step 5262 (time=26.31), 0.520104 s/step
# on time step 5272 (time=26.36), 0.408554 s/step
# on time step 5285 (time=26.425), 0.316966 s/step
# on time step 5298 (time=26.49), 0.335576 s/step
# on time step 5305 (time=26.525), 0.598764 s/step
# on time step 5312 (time=26.56), 0.601146 s/step
# on time step 5319 (time=26.595), 0.59902 s/step
# on time step 5326 (time=26.63), 0.599141 s/step
# on time step 5333 (time=26.665), 0.601947 s/step
# on time step 5340 (time=26.7), 0.598642 s/step
# on time step 5347 (time=26.735), 0.610189 s/step
# on time step 5354 (time=26.77), 0.598998 s/step
# on time step 5361 (time=26.805), 0.611741 s/step
# on time step 5368 (time=26.84), 0.601063 s/step
# on time step 5375 (time=26.875), 0.609416 s/step
# on time step 5382 (time=26.91), 0.594463 s/step
# on time step 5389 (time=26.945), 0.599621 s/step
# on time step 5396 (time=26.98), 0.608171 s/step
# on time step 5403 (time=27.015), 0.59942 s/step
# on time step 5410 (time=27.05), 0.605804 s/step
# on time step 5417 (time=27.085), 0.600398 s/step
# on time step 5424 (time=27.12), 0.599919 s/step
# on time step 5431 (time=27.155), 0.601344 s/step
# on time step 5438 (time=27.19), 0.599824 s/step
# on time step 5445 (time=27.225), 0.600354 s/step
# on time step 5452 (time=27.26), 0.59917 s/step
# on time step 5463 (time=27.315), 0.385615 s/step
# on time step 5472 (time=27.36), 0.472431 s/step
# on time step 5481 (time=27.405), 0.447059 s/step
# on time step 5491 (time=27.455), 0.443211 s/step
# on time step 5500 (time=27.5), 0.445188 s/step
# on time step 5509 (time=27.545), 0.473511 s/step
# on time step 5518 (time=27.59), 0.447677 s/step
# on time step 5527 (time=27.635), 0.452511 s/step
# on time step 5536 (time=27.68), 0.451811 s/step
# on time step 5545 (time=27.725), 0.447157 s/step
# on time step 5554 (time=27.77), 0.468821 s/step
# on time step 5563 (time=27.815), 0.453118 s/step
# on time step 5572 (time=27.86), 0.445137 s/step
# on time step 5582 (time=27.91), 0.441468 s/step
# on time step 5591 (time=27.955), 0.444516 s/step
# on time step 5600 (time=28), 0.444977 s/step
# on time step 5610 (time=28.05), 0.442475 s/step
# on time step 5619 (time=28.095), 0.451295 s/step
# on time step 5628 (time=28.14), 0.450249 s/step
# on time step 5637 (time=28.185), 0.451618 s/step
# on time step 5646 (time=28.23), 0.45822 s/step
# on time step 5656 (time=28.28), 0.44195 s/step
# on time step 5665 (time=28.325), 0.444756 s/step
# on time step 5674 (time=28.37), 0.446643 s/step
# on time step 5683 (time=28.415), 0.453423 s/step
# on time step 5692 (time=28.46), 0.44681 s/step
# on time step 5701 (time=28.505), 0.450612 s/step
# on time step 5711 (time=28.555), 0.438748 s/step
# on time step 5721 (time=28.605), 0.437766 s/step
# on time step 5731 (time=28.655), 0.448956 s/step
# on time step 5740 (time=28.7), 0.451136 s/step
# on time step 5750 (time=28.75), 0.405725 s/step
# on time step 5759 (time=28.795), 0.450089 s/step
# on time step 5766 (time=28.83), 0.608806 s/step
# on time step 5773 (time=28.865), 0.619344 s/step
# on time step 5780 (time=28.9), 0.628063 s/step
# on time step 5787 (time=28.935), 0.632203 s/step
# on time step 5794 (time=28.97), 0.622686 s/step
# on time step 5801 (time=29.005), 0.629825 s/step
# on time step 5808 (time=29.04), 0.620136 s/step
# on time step 5815 (time=29.075), 0.625304 s/step
# on time step 5822 (time=29.11), 0.618631 s/step
# on time step 5829 (time=29.145), 0.619705 s/step
# on time step 5836 (time=29.18), 0.620968 s/step
# on time step 5843 (time=29.215), 0.625381 s/step
# on time step 5850 (time=29.25), 0.626114 s/step
# on time step 5857 (time=29.285), 0.623276 s/step
# on time step 5864 (time=29.32), 0.626739 s/step
# on time step 5871 (time=29.355), 0.611116 s/step
# on time step 5878 (time=29.39), 0.624926 s/step
# on time step 5885 (time=29.425), 0.657913 s/step
# on time step 5892 (time=29.46), 0.660364 s/step
# on time step 5899 (time=29.495), 0.66386 s/step
# on time step 5907 (time=29.535), 0.548706 s/step
# on time step 5916 (time=29.58), 0.488148 s/step
# on time step 5925 (time=29.625), 0.471453 s/step
# on time step 5933 (time=29.665), 0.510454 s/step
# on time step 5941 (time=29.705), 0.516049 s/step
# on time step 5950 (time=29.75), 0.481882 s/step
# on time step 5959 (time=29.795), 0.481176 s/step
# on time step 5968 (time=29.84), 0.473083 s/step
# on time step 5977 (time=29.885), 0.514373 s/step
# on time step 5983 (time=29.915), 0.771187 s/step
# on time step 5989 (time=29.945), 0.770965 s/step
# on time step 5995 (time=29.975), 0.759787 s/step
# on time step 5999 (time=29.995), 1.03847 s/step
# on time step 6005 (time=30.025), 0.68315 s/step
# on time step 6011 (time=30.055), 0.688705 s/step
# on time step 6017 (time=30.085), 0.754277 s/step
# on time step 6023 (time=30.115), 0.69446 s/step
# on time step 6029 (time=30.145), 0.746347 s/step
# on time step 6035 (time=30.175), 0.697135 s/step
# on time step 6041 (time=30.205), 0.702984 s/step
# on time step 6047 (time=30.235), 0.68612 s/step
# on time step 6053 (time=30.265), 0.708886 s/step
# on time step 6059 (time=30.295), 0.70592 s/step
# on time step 6065 (time=30.325), 0.688449 s/step
# on time step 6071 (time=30.355), 0.690397 s/step
# on time step 6077 (time=30.385), 0.694204 s/step
# on time step 6083 (time=30.415), 0.704054 s/step
# on time step 6089 (time=30.445), 0.717174 s/step
# on time step 6095 (time=30.475), 0.694979 s/step
# on time step 6101 (time=30.505), 0.695896 s/step
# on time step 6107 (time=30.535), 0.6886 s/step
# on time step 6113 (time=30.565), 0.685934 s/step
# on time step 6119 (time=30.595), 0.682725 s/step
# on time step 6125 (time=30.625), 0.68751 s/step
# on time step 6131 (time=30.655), 0.688328 s/step
# on time step 6137 (time=30.685), 0.677737 s/step
# on time step 6143 (time=30.715), 0.702124 s/step
# on time step 6149 (time=30.745), 0.702565 s/step
# on time step 6155 (time=30.775), 0.701661 s/step
# on time step 6161 (time=30.805), 0.68439 s/step
# on time step 6167 (time=30.835), 0.692052 s/step
# on time step 6173 (time=30.865), 0.700835 s/step
# on time step 6179 (time=30.895), 0.68671 s/step
# on time step 6185 (time=30.925), 0.691245 s/step
# on time step 6191 (time=30.955), 0.700552 s/step
# on time step 6197 (time=30.985), 0.676836 s/step
# on time step 6204 (time=31.02), 0.642794 s/step
# on time step 6211 (time=31.055), 0.645381 s/step
# on time step 6218 (time=31.09), 0.644628 s/step
# on time step 6225 (time=31.125), 0.646805 s/step
# on time step 6231 (time=31.155), 0.674986 s/step
# on time step 6238 (time=31.19), 0.636924 s/step
# on time step 6245 (time=31.225), 0.625041 s/step
# on time step 6256 (time=31.28), 0.375798 s/step
# on time step 6265 (time=31.325), 0.479739 s/step
# on time step 6274 (time=31.37), 0.494321 s/step
# on time step 6283 (time=31.415), 0.50034 s/step
# on time step 6292 (time=31.46), 0.47777 s/step
# on time step 6301 (time=31.505), 0.476059 s/step
# on time step 6310 (time=31.55), 0.474594 s/step
# on time step 6319 (time=31.595), 0.47364 s/step
# on time step 6328 (time=31.64), 0.476047 s/step
# on time step 6337 (time=31.685), 0.483964 s/step
# on time step 6346 (time=31.73), 0.481098 s/step
# on time step 6354 (time=31.77), 0.503201 s/step
# on time step 6363 (time=31.815), 0.486116 s/step
# on time step 6372 (time=31.86), 0.472804 s/step
# on time step 6381 (time=31.905), 0.474131 s/step
# on time step 6390 (time=31.95), 0.473196 s/step
# on time step 6399 (time=31.995), 0.475238 s/step
# on time step 6408 (time=32.04), 0.470325 s/step
# on time step 6417 (time=32.085), 0.478826 s/step
# on time step 6426 (time=32.13), 0.480409 s/step
# on time step 6435 (time=32.175), 0.479589 s/step
# on time step 6444 (time=32.22), 0.48561 s/step
# on time step 6453 (time=32.265), 0.479605 s/step
# on time step 6462 (time=32.31), 0.489766 s/step
# on time step 6471 (time=32.355), 0.484435 s/step
# on time step 6480 (time=32.4), 0.478168 s/step
# on time step 6489 (time=32.445), 0.474488 s/step
# on time step 6498 (time=32.49), 0.465531 s/step
# on time step 6507 (time=32.535), 0.46697 s/step
# on time step 6516 (time=32.58), 0.477258 s/step
# on time step 6525 (time=32.625), 0.480523 s/step
# on time step 6534 (time=32.67), 0.491008 s/step
# on time step 6543 (time=32.715), 0.481173 s/step
# on time step 6552 (time=32.76), 0.48019 s/step
# on time step 6561 (time=32.805), 0.480234 s/step
# on time step 6570 (time=32.85), 0.484309 s/step
# on time step 6579 (time=32.895), 0.480406 s/step
# on time step 6588 (time=32.94), 0.481467 s/step
# on time step 6597 (time=32.985), 0.476209 s/step
# on time step 6606 (time=33.03), 0.47544 s/step
# on time step 6615 (time=33.075), 0.477403 s/step
# on time step 6624 (time=33.12), 0.479946 s/step
# on time step 6633 (time=33.165), 0.486516 s/step
# on time step 6642 (time=33.21), 0.476737 s/step
# on time step 6651 (time=33.255), 0.486975 s/step
# on time step 6665 (time=33.325), 0.287099 s/step
# on time step 6675 (time=33.375), 0.42421 s/step
# on time step 6686 (time=33.43), 0.408102 s/step
# on time step 6693 (time=33.465), 0.598727 s/step
# on time step 6700 (time=33.5), 0.613616 s/step
# on time step 6707 (time=33.535), 0.602521 s/step
# on time step 6714 (time=33.57), 0.60372 s/step
# on time step 6721 (time=33.605), 0.611931 s/step
# on time step 6728 (time=33.64), 0.610215 s/step
# on time step 6735 (time=33.675), 0.61154 s/step
# on time step 6742 (time=33.71), 0.611265 s/step
# on time step 6749 (time=33.745), 0.609106 s/step
# on time step 6756 (time=33.78), 0.610614 s/step
# on time step 6763 (time=33.815), 0.611163 s/step
# on time step 6770 (time=33.85), 0.613377 s/step
# on time step 6777 (time=33.885), 0.609787 s/step
# on time step 6784 (time=33.92), 0.612151 s/step
# on time step 6791 (time=33.955), 0.610401 s/step
# on time step 6798 (time=33.99), 0.613977 s/step
# on time step 6805 (time=34.025), 0.61215 s/step
# on time step 6812 (time=34.06), 0.609821 s/step
# on time step 6819 (time=34.095), 0.615924 s/step
# on time step 6826 (time=34.13), 0.614583 s/step
# on time step 6833 (time=34.165), 0.612533 s/step
# on time step 6840 (time=34.2), 0.611769 s/step
# on time step 6847 (time=34.235), 0.611183 s/step
# on time step 6854 (time=34.27), 0.611889 s/step
# on time step 6861 (time=34.305), 0.61081 s/step
# on time step 6868 (time=34.34), 0.610851 s/step
# on time step 6875 (time=34.375), 0.612373 s/step
# on time step 6882 (time=34.41), 0.611905 s/step
# on time step 6889 (time=34.445), 0.611521 s/step
# on time step 6896 (time=34.48), 0.6144 s/step
# on time step 6903 (time=34.515), 0.623734 s/step
# on time step 6910 (time=34.55), 0.609092 s/step
# on time step 6917 (time=34.585), 0.625055 s/step
# on time step 6924 (time=34.62), 0.610658 s/step
# on time step 6931 (time=34.655), 0.622955 s/step
# on time step 6938 (time=34.69), 0.614891 s/step
# on time step 6945 (time=34.725), 0.615043 s/step
# on time step 6952 (time=34.76), 0.619946 s/step
# on time step 6959 (time=34.795), 0.618638 s/step
# on time step 6966 (time=34.83), 0.618364 s/step
# on time step 6973 (time=34.865), 0.611145 s/step
# on time step 6980 (time=34.9), 0.613217 s/step
# on time step 6986 (time=34.93), 0.686117 s/step
# on time step 6992 (time=34.96), 0.698734 s/step
# on time step 6998 (time=34.99), 0.697564 s/step
# on time step 7004 (time=35.02), 0.698321 s/step
# on time step 7010 (time=35.05), 0.700895 s/step
# on time step 7017 (time=35.085), 0.641887 s/step
# on time step 7025 (time=35.125), 0.529033 s/step
# on time step 7033 (time=35.165), 0.528868 s/step
# on time step 7040 (time=35.2), 0.602071 s/step
# on time step 7047 (time=35.235), 0.60343 s/step
# on time step 7054 (time=35.27), 0.597842 s/step
# on time step 7061 (time=35.305), 0.589505 s/step
# on time step 7068 (time=35.34), 0.5906 s/step
# on time step 7075 (time=35.375), 0.588322 s/step
# on time step 7082 (time=35.41), 0.590218 s/step
# on time step 7089 (time=35.445), 0.592264 s/step
# on time step 7096 (time=35.48), 0.584824 s/step
# on time step 7103 (time=35.515), 0.592157 s/step
# on time step 7110 (time=35.55), 0.587861 s/step
# on time step 7117 (time=35.585), 0.5917 s/step
# on time step 7124 (time=35.62), 0.587052 s/step
# on time step 7131 (time=35.655), 0.589646 s/step
# on time step 7138 (time=35.69), 0.589717 s/step
# on time step 7145 (time=35.725), 0.589857 s/step
# on time step 7152 (time=35.76), 0.600753 s/step
# on time step 7159 (time=35.795), 0.589689 s/step
# on time step 7166 (time=35.83), 0.601125 s/step
# on time step 7173 (time=35.865), 0.587984 s/step
# on time step 7180 (time=35.9), 0.596498 s/step
# on time step 7187 (time=35.935), 0.58516 s/step
# on time step 7194 (time=35.97), 0.587765 s/step
# on time step 7201 (time=36.005), 0.594116 s/step
# on time step 7208 (time=36.04), 0.584534 s/step
# on time step 7215 (time=36.075), 0.588513 s/step
# on time step 7222 (time=36.11), 0.581646 s/step
# on time step 7234 (time=36.17), 0.345063 s/step
# on time step 7243 (time=36.215), 0.44495 s/step
# on time step 7253 (time=36.265), 0.428356 s/step
# on time step 7263 (time=36.315), 0.430684 s/step
# on time step 7272 (time=36.36), 0.465442 s/step
# on time step 7282 (time=36.41), 0.433078 s/step
# on time step 7292 (time=36.46), 0.433176 s/step
# on time step 7302 (time=36.51), 0.431497 s/step
# on time step 7311 (time=36.555), 0.456962 s/step
# on time step 7321 (time=36.605), 0.438865 s/step
# on time step 7331 (time=36.655), 0.430017 s/step
# on time step 7341 (time=36.705), 0.432831 s/step
# on time step 7351 (time=36.755), 0.435617 s/step
# on time step 7360 (time=36.8), 0.455899 s/step
# on time step 7369 (time=36.845), 0.453599 s/step
# on time step 7379 (time=36.895), 0.435087 s/step
# on time step 7389 (time=36.945), 0.43478 s/step
# on time step 7399 (time=36.995), 0.435754 s/step
# on time step 7409 (time=37.045), 0.434007 s/step
# on time step 7419 (time=37.095), 0.435256 s/step
# on time step 7429 (time=37.145), 0.436975 s/step
# on time step 7439 (time=37.195), 0.449419 s/step
# on time step 7449 (time=37.245), 0.443625 s/step
# on time step 7458 (time=37.29), 0.445352 s/step
# on time step 7468 (time=37.34), 0.436507 s/step
# on time step 7478 (time=37.39), 0.434197 s/step
# on time step 7488 (time=37.44), 0.437489 s/step
# on time step 7498 (time=37.49), 0.431999 s/step
# on time step 7508 (time=37.54), 0.409039 s/step
# on time step 7519 (time=37.595), 0.38036 s/step
# on time step 7529 (time=37.645), 0.453962 s/step
# on time step 7535 (time=37.675), 0.681754 s/step
# on time step 7541 (time=37.705), 0.679236 s/step
# on time step 7547 (time=37.735), 0.693755 s/step
# on time step 7553 (time=37.765), 0.69576 s/step
# on time step 7559 (time=37.795), 0.682224 s/step
# on time step 7565 (time=37.825), 0.692952 s/step
# on time step 7571 (time=37.855), 0.691323 s/step
# on time step 7577 (time=37.885), 0.686323 s/step
# on time step 7583 (time=37.915), 0.67862 s/step
# on time step 7589 (time=37.945), 0.682013 s/step
# on time step 7595 (time=37.975), 0.681163 s/step
# on time step 7601 (time=38.005), 0.683477 s/step
# on time step 7607 (time=38.035), 0.680622 s/step
# on time step 7613 (time=38.065), 0.682837 s/step
# on time step 7619 (time=38.095), 0.680077 s/step
# on time step 7625 (time=38.125), 0.68182 s/step
# on time step 7632 (time=38.16), 0.645855 s/step
# on time step 7639 (time=38.195), 0.646084 s/step
# on time step 7646 (time=38.23), 0.658646 s/step
# on time step 7653 (time=38.265), 0.649417 s/step
# on time step 7660 (time=38.3), 0.641043 s/step
# on time step 7668 (time=38.34), 0.54294 s/step
# on time step 7676 (time=38.38), 0.520539 s/step
# on time step 7682 (time=38.41), 0.761491 s/step
# on time step 7689 (time=38.445), 0.663207 s/step
# on time step 7695 (time=38.475), 0.667674 s/step
# on time step 7701 (time=38.505), 0.68365 s/step
# on time step 7708 (time=38.54), 0.66482 s/step
# on time step 7714 (time=38.57), 0.675223 s/step
# on time step 7721 (time=38.605), 0.66613 s/step
# on time step 7727 (time=38.635), 0.671466 s/step
# on time step 7734 (time=38.67), 0.661073 s/step
# on time step 7741 (time=38.705), 0.66272 s/step
# on time step 7747 (time=38.735), 0.668344 s/step
# on time step 7754 (time=38.77), 0.662634 s/step
# on time step 7761 (time=38.805), 0.657879 s/step
# on time step 7768 (time=38.84), 0.663124 s/step
# on time step 7775 (time=38.875), 0.665797 s/step
# ...
# on time step 13161 (time=65.805), 0.674159 s/step
# on time step 13167 (time=65.835), 0.684126 s/step
# on time step 13173 (time=65.865), 0.669352 s/step
# on time step 13179 (time=65.895), 0.686167 s/step
# on time step 13185 (time=65.925), 0.673077 s/step
# on time step 13191 (time=65.955), 0.673524 s/step
# on time step 13198 (time=65.99), 0.648224 s/step
# on time step 13205 (time=66.025), 0.640472 s/step
# on time step 13212 (time=66.06), 0.6444 s/step
# on time step 13219 (time=66.095), 0.646889 s/step
# on time step 13226 (time=66.13), 0.640921 s/step
# on time step 13233 (time=66.165), 0.64545 s/step
# on time step 13240 (time=66.2), 0.641026 s/step
# on time step 13247 (time=66.235), 0.623652 s/step
# on time step 13254 (time=66.27), 0.608757 s/step
# on time step 13261 (time=66.305), 0.609816 s/step
# on time step 13268 (time=66.34), 0.609975 s/step
# on time step 13275 (time=66.375), 0.607645 s/step
# on time step 13282 (time=66.41), 0.607964 s/step
# on time step 13289 (time=66.445), 0.610347 s/step
# on time step 13296 (time=66.48), 0.606331 s/step
# on time step 13303 (time=66.515), 0.607374 s/step
# on time step 13310 (time=66.55), 0.607571 s/step
# on time step 13317 (time=66.585), 0.606804 s/step
# on time step 13324 (time=66.62), 0.612496 s/step
# on time step 13331 (time=66.655), 0.613021 s/step
# on time step 13338 (time=66.69), 0.609538 s/step
# on time step 13345 (time=66.725), 0.607341 s/step
# on time step 13352 (time=66.76), 0.613246 s/step
# on time step 13359 (time=66.795), 0.620046 s/step
# on time step 13366 (time=66.83), 0.613548 s/step
# on time step 13373 (time=66.865), 0.620227 s/step
# on time step 13380 (time=66.9), 0.607607 s/step
# on time step 13387 (time=66.935), 0.61125 s/step
# on time step 13394 (time=66.97), 0.618195 s/step
# on time step 13401 (time=67.005), 0.606454 s/step
# on time step 13408 (time=67.04), 0.616015 s/step
# on time step 13415 (time=67.075), 0.607133 s/step
# on time step 13422 (time=67.11), 0.610226 s/step
# on time step 13429 (time=67.145), 0.605694 s/step
# on time step 13436 (time=67.18), 0.602363 s/step
# on time step 13443 (time=67.215), 0.609718 s/step
# on time step 13450 (time=67.25), 0.607288 s/step
# on time step 13457 (time=67.285), 0.607262 s/step
# on time step 13465 (time=67.325), 0.542966 s/step
# on time step 13472 (time=67.36), 0.579663 s/step
# on time step 13479 (time=67.395), 0.609298 s/step
# on time step 13485 (time=67.425), 0.669632 s/step
# on time step 13492 (time=67.46), 0.666953 s/step
# on time step 13498 (time=67.49), 0.669879 s/step
# on time step 13504 (time=67.52), 0.668545 s/step
# on time step 13510 (time=67.55), 0.669576 s/step
# on time step 13516 (time=67.58), 0.667174 s/step
# on time step 13522 (time=67.61), 0.673526 s/step
# on time step 13528 (time=67.64), 0.673139 s/step
# on time step 13534 (time=67.67), 0.669267 s/step
# on time step 13540 (time=67.7), 0.672154 s/step
# on time step 13546 (time=67.73), 0.67236 s/step
# on time step 13552 (time=67.76), 0.671367 s/step
# on time step 13558 (time=67.79), 0.669674 s/step
# on time step 13564 (time=67.82), 0.670714 s/step
# on time step 13570 (time=67.85), 0.672229 s/step
# on time step 13576 (time=67.88), 0.671141 s/step
# on time step 13582 (time=67.91), 0.681441 s/step
# on time step 13588 (time=67.94), 0.669957 s/step
# on time step 13594 (time=67.97), 0.673751 s/step
# on time step 13600 (time=68), 0.681306 s/step
# on time step 13606 (time=68.03), 0.671918 s/step
# on time step 13612 (time=68.06), 0.679557 s/step
# on time step 13618 (time=68.09), 0.668405 s/step
# on time step 13624 (time=68.12), 0.670902 s/step
# on time step 13630 (time=68.15), 0.677783 s/step
# on time step 13636 (time=68.18), 0.679676 s/step
# on time step 13642 (time=68.21), 0.671208 s/step
# on time step 13652 (time=68.26), 0.413902 s/step
# on time step 13659 (time=68.295), 0.624078 s/step
# on time step 13666 (time=68.33), 0.628859 s/step
# on time step 13673 (time=68.365), 0.628613 s/step
# on time step 13680 (time=68.4), 0.621076 s/step
# on time step 13687 (time=68.435), 0.623741 s/step
# on time step 13694 (time=68.47), 0.629125 s/step
# on time step 13701 (time=68.505), 0.625047 s/step
# on time step 13708 (time=68.54), 0.629683 s/step
# on time step 13715 (time=68.575), 0.624648 s/step
# on time step 13722 (time=68.61), 0.624083 s/step
# on time step 13729 (time=68.645), 0.626768 s/step
# on time step 13736 (time=68.68), 0.627155 s/step
# on time step 13743 (time=68.715), 0.627185 s/step
# on time step 13750 (time=68.75), 0.603154 s/step
# on time step 13757 (time=68.785), 0.6004 s/step
# on time step 13764 (time=68.82), 0.600196 s/step
# on time step 13771 (time=68.855), 0.599342 s/step
# on time step 13778 (time=68.89), 0.599538 s/step
# on time step 13785 (time=68.925), 0.600505 s/step
# on time step 13792 (time=68.96), 0.597818 s/step
# on time step 13799 (time=68.995), 0.601259 s/step
# on time step 13806 (time=69.03), 0.601512 s/step
# on time step 13813 (time=69.065), 0.610155 s/step
# on time step 13820 (time=69.1), 0.60062 s/step
# on time step 13827 (time=69.135), 0.610586 s/step
# on time step 13834 (time=69.17), 0.597771 s/step
# on time step 13841 (time=69.205), 0.608551 s/step
# on time step 13848 (time=69.24), 0.600774 s/step
# on time step 13855 (time=69.275), 0.597714 s/step
# on time step 13862 (time=69.31), 0.607049 s/step
# on time step 13869 (time=69.345), 0.596989 s/step
# on time step 13876 (time=69.38), 0.607526 s/step
# on time step 13883 (time=69.415), 0.598238 s/step
# on time step 13890 (time=69.45), 0.599148 s/step
# on time step 13902 (time=69.51), 0.347107 s/step
# on time step 13909 (time=69.545), 0.606891 s/step
# on time step 13916 (time=69.58), 0.620385 s/step
# on time step 13925 (time=69.625), 0.508961 s/step
# on time step 13934 (time=69.67), 0.49732 s/step
# on time step 13940 (time=69.7), 0.727114 s/step
# on time step 13946 (time=69.73), 0.725456 s/step
# on time step 13952 (time=69.76), 0.730794 s/step
# on time step 13958 (time=69.79), 0.729439 s/step
# on time step 13964 (time=69.82), 0.729532 s/step
# on time step 13970 (time=69.85), 0.725368 s/step
# on time step 13976 (time=69.88), 0.729681 s/step
# on time step 13982 (time=69.91), 0.732811 s/step
# on time step 13988 (time=69.94), 0.738388 s/step
# on time step 13994 (time=69.97), 0.73126 s/step
# on time step 14000 (time=70), 0.729286 s/step
# on time step 14006 (time=70.03), 0.730699 s/step
# on time step 14012 (time=70.06), 0.733219 s/step
# on time step 14018 (time=70.09), 0.731053 s/step
# on time step 14024 (time=70.12), 0.724288 s/step
# on time step 14030 (time=70.15), 0.720972 s/step
# on time step 14036 (time=70.18), 0.746155 s/step
# on time step 14042 (time=70.21), 0.723556 s/step
# on time step 14048 (time=70.24), 0.738378 s/step
# on time step 14054 (time=70.27), 0.728831 s/step
# on time step 14060 (time=70.3), 0.742718 s/step
# on time step 14066 (time=70.33), 0.720557 s/step
# on time step 14072 (time=70.36), 0.732412 s/step
# on time step 14078 (time=70.39), 0.741834 s/step
# on time step 14084 (time=70.42), 0.690358 s/step
# on time step 14090 (time=70.45), 0.682783 s/step
# on time step 14096 (time=70.48), 0.669319 s/step
# on time step 14102 (time=70.51), 0.669117 s/step
# on time step 14108 (time=70.54), 0.671752 s/step
# on time step 14114 (time=70.57), 0.666694 s/step
# on time step 14121 (time=70.605), 0.663753 s/step
# on time step 14128 (time=70.64), 0.667605 s/step
# on time step 14134 (time=70.67), 0.670136 s/step
# on time step 14141 (time=70.705), 0.656476 s/step
# on time step 14148 (time=70.74), 0.635594 s/step
# on time step 14155 (time=70.775), 0.636446 s/step
# on time step 14162 (time=70.81), 0.627589 s/step
# on time step 14169 (time=70.845), 0.632318 s/step
# on time step 14176 (time=70.88), 0.628513 s/step
# on time step 14183 (time=70.915), 0.63115 s/step
# on time step 14190 (time=70.95), 0.634637 s/step
# on time step 14197 (time=70.985), 0.629464 s/step
# on time step 14204 (time=71.02), 0.633729 s/step
# on time step 14211 (time=71.055), 0.623863 s/step
# on time step 14218 (time=71.09), 0.628459 s/step
# on time step 14225 (time=71.125), 0.632507 s/step
# on time step 14232 (time=71.16), 0.645576 s/step
# on time step 14239 (time=71.195), 0.644266 s/step
# on time step 14246 (time=71.23), 0.64174 s/step
# on time step 14253 (time=71.265), 0.629529 s/step
# on time step 14260 (time=71.3), 0.64446 s/step
# on time step 14267 (time=71.335), 0.628714 s/step
# on time step 14274 (time=71.37), 0.632463 s/step
# on time step 14281 (time=71.405), 0.615082 s/step
# on time step 14288 (time=71.44), 0.613315 s/step
# on time step 14295 (time=71.475), 0.624387 s/step
# on time step 14302 (time=71.51), 0.614681 s/step
# on time step 14309 (time=71.545), 0.622485 s/step
# on time step 14316 (time=71.58), 0.61538 s/step
# on time step 14323 (time=71.615), 0.618293 s/step
# on time step 14330 (time=71.65), 0.614973 s/step
# on time step 14337 (time=71.685), 0.614955 s/step
# on time step 14344 (time=71.72), 0.612557 s/step
# on time step 14351 (time=71.755), 0.616038 s/step
# on time step 14358 (time=71.79), 0.611508 s/step
# on time step 14365 (time=71.825), 0.610777 s/step
# on time step 14371 (time=71.855), 0.688509 s/step
# on time step 14377 (time=71.885), 0.707209 s/step
# on time step 14383 (time=71.915), 0.721391 s/step
# on time step 14389 (time=71.945), 0.717704 s/step
# on time step 14395 (time=71.975), 0.721738 s/step
# on time step 14401 (time=72.005), 0.72883 s/step
# on time step 14407 (time=72.035), 0.72179 s/step
# on time step 14419 (time=72.095), 0.357332 s/step
# on time step 14425 (time=72.125), 0.692482 s/step
# on time step 14431 (time=72.155), 0.678139 s/step
# on time step 14437 (time=72.185), 0.681076 s/step
# on time step 14443 (time=72.215), 0.67781 s/step
# on time step 14449 (time=72.245), 0.679044 s/step
# on time step 14455 (time=72.275), 0.679666 s/step
# on time step 14461 (time=72.305), 0.682929 s/step
# on time step 14467 (time=72.335), 0.676935 s/step
# on time step 14473 (time=72.365), 0.680081 s/step
# on time step 14479 (time=72.395), 0.684376 s/step
# on time step 14485 (time=72.425), 0.676847 s/step
# on time step 14491 (time=72.455), 0.673372 s/step
# on time step 14497 (time=72.485), 0.688629 s/step
# on time step 14503 (time=72.515), 0.681163 s/step
# on time step 14509 (time=72.545), 0.687689 s/step
# on time step 14515 (time=72.575), 0.679327 s/step
# on time step 14521 (time=72.605), 0.676104 s/step
# on time step 14527 (time=72.635), 0.687317 s/step
# on time step 14533 (time=72.665), 0.676973 s/step
# on time step 14539 (time=72.695), 0.681294 s/step
# on time step 14545 (time=72.725), 0.680615 s/step
# on time step 14551 (time=72.755), 0.678137 s/step
# on time step 14557 (time=72.785), 0.683222 s/step
# on time step 14563 (time=72.815), 0.685648 s/step
# on time step 14569 (time=72.845), 0.687755 s/step
# on time step 14575 (time=72.875), 0.683726 s/step
# on time step 14581 (time=72.905), 0.682982 s/step
# on time step 14587 (time=72.935), 0.683009 s/step
# on time step 14593 (time=72.965), 0.683182 s/step
# on time step 14599 (time=72.995), 0.678312 s/step
# on time step 14605 (time=73.025), 0.684263 s/step
# on time step 14611 (time=73.055), 0.681483 s/step
# on time step 14617 (time=73.085), 0.666717 s/step
# on time step 14631 (time=73.155), 0.315579 s/step
# on time step 14645 (time=73.225), 0.298709 s/step
# on time step 14653 (time=73.265), 0.520838 s/step
# on time step 14660 (time=73.3), 0.642221 s/step
# on time step 14667 (time=73.335), 0.671622 s/step
# on time step 14674 (time=73.37), 0.659777 s/step
# on time step 14681 (time=73.405), 0.650685 s/step
# on time step 14688 (time=73.44), 0.651498 s/step
# on time step 14695 (time=73.475), 0.656818 s/step
# on time step 14701 (time=73.505), 0.686392 s/step
# on time step 14708 (time=73.54), 0.65667 s/step
# on time step 14715 (time=73.575), 0.661961 s/step
# on time step 14722 (time=73.61), 0.650848 s/step
# on time step 14729 (time=73.645), 0.652415 s/step
# on time step 14735 (time=73.675), 0.672026 s/step
# on time step 14741 (time=73.705), 0.671998 s/step
# on time step 14748 (time=73.74), 0.65205 s/step
# on time step 14756 (time=73.78), 0.556621 s/step
# on time step 14765 (time=73.825), 0.466026 s/step
# on time step 14774 (time=73.87), 0.468276 s/step
# on time step 14783 (time=73.915), 0.469209 s/step
# on time step 14792 (time=73.96), 0.472715 s/step
# on time step 14801 (time=74.005), 0.47853 s/step
# on time step 14810 (time=74.05), 0.469528 s/step
# on time step 14819 (time=74.095), 0.470704 s/step
# on time step 14828 (time=74.14), 0.466911 s/step
# on time step 14837 (time=74.185), 0.469964 s/step
# on time step 14846 (time=74.23), 0.463856 s/step
# on time step 14855 (time=74.275), 0.467169 s/step
# on time step 14864 (time=74.32), 0.466575 s/step
# on time step 14873 (time=74.365), 0.468989 s/step
# on time step 14882 (time=74.41), 0.460814 s/step
# on time step 14891 (time=74.455), 0.463973 s/step
# on time step 14901 (time=74.505), 0.420953 s/step
# on time step 14913 (time=74.565), 0.3498 s/step
# on time step 14923 (time=74.615), 0.424069 s/step
# on time step 14932 (time=74.66), 0.465576 s/step
# on time step 14941 (time=74.705), 0.46309 s/step
# on time step 14950 (time=74.75), 0.462383 s/step
# on time step 14959 (time=74.795), 0.45895 s/step
# on time step 14968 (time=74.84), 0.462241 s/step
# on time step 14977 (time=74.885), 0.46175 s/step
# on time step 14986 (time=74.93), 0.462018 s/step
# on time step 14995 (time=74.975), 0.457495 s/step
# on time step 15004 (time=75.02), 0.459799 s/step
# on time step 15013 (time=75.065), 0.463993 s/step
# on time step 15022 (time=75.11), 0.462086 s/step
# on time step 15031 (time=75.155), 0.460302 s/step
# on time step 15040 (time=75.2), 0.461797 s/step
# on time step 15049 (time=75.245), 0.461859 s/step
# on time step 15058 (time=75.29), 0.462149 s/step
# on time step 15067 (time=75.335), 0.461895 s/step
# on time step 15076 (time=75.38), 0.463147 s/step
# on time step 15085 (time=75.425), 0.460219 s/step
# on time step 15094 (time=75.47), 0.469648 s/step
# on time step 15103 (time=75.515), 0.475089 s/step
# on time step 15112 (time=75.56), 0.467289 s/step
# on time step 15121 (time=75.605), 0.477046 s/step
# on time step 15129 (time=75.645), 0.526092 s/step
# on time step 15135 (time=75.675), 0.80148 s/step
# on time step 15140 (time=75.7), 0.801949 s/step
# on time step 15146 (time=75.73), 0.79313 s/step
# on time step 15155 (time=75.775), 0.493338 s/step
# on time step 15164 (time=75.82), 0.458822 s/step
# on time step 15173 (time=75.865), 0.462254 s/step
# on time step 15182 (time=75.91), 0.460587 s/step
# on time step 15191 (time=75.955), 0.469437 s/step
# on time step 15200 (time=76), 0.472289 s/step
# on time step 15209 (time=76.045), 0.467296 s/step
# on time step 15218 (time=76.09), 0.468333 s/step
# on time step 15227 (time=76.135), 0.462218 s/step
# on time step 15236 (time=76.18), 0.467068 s/step
# on time step 15245 (time=76.225), 0.468654 s/step
# on time step 15260 (time=76.3), 0.273856 s/step
# on time step 15267 (time=76.335), 0.589 s/step
# on time step 15274 (time=76.37), 0.58727 s/step
# on time step 15281 (time=76.405), 0.592125 s/step
# on time step 15288 (time=76.44), 0.588983 s/step
# on time step 15295 (time=76.475), 0.59381 s/step
# on time step 15302 (time=76.51), 0.590808 s/step
# on time step 15309 (time=76.545), 0.591092 s/step
# on time step 15316 (time=76.58), 0.588962 s/step
# on time step 15323 (time=76.615), 0.593383 s/step
# on time step 15330 (time=76.65), 0.592709 s/step
# on time step 15337 (time=76.685), 0.592344 s/step
# on time step 15344 (time=76.72), 0.589608 s/step
# on time step 15351 (time=76.755), 0.591122 s/step
# on time step 15360 (time=76.8), 0.489787 s/step
# on time step 15370 (time=76.85), 0.440485 s/step
# on time step 15379 (time=76.895), 0.44662 s/step
# on time step 15388 (time=76.94), 0.446546 s/step
# on time step 15397 (time=76.985), 0.445662 s/step
# on time step 15407 (time=77.035), 0.441473 s/step
# on time step 15417 (time=77.085), 0.433833 s/step
# on time step 15427 (time=77.135), 0.429294 s/step
# on time step 15437 (time=77.185), 0.437535 s/step
# on time step 15447 (time=77.235), 0.437369 s/step
# on time step 15457 (time=77.285), 0.436258 s/step
# on time step 15467 (time=77.335), 0.440522 s/step
# on time step 15477 (time=77.385), 0.431495 s/step
# on time step 15487 (time=77.435), 0.438691 s/step
# on time step 15497 (time=77.485), 0.43335 s/step
# run 0 finished at t = 77.5 (15500 timesteps)

# %%
Ex_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ex,0)
Ey_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ey,0)
Ez_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_xz.npy',Ex_xz)
np.save('DFT_GAS/Dft_GAS_Ey_xz.npy',Ey_xz)
np.save('DFT_GAS/Dft_GAS_Ez_xz.npy',Ez_xz)

Ex_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ex,0)
Ey_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ey,0)
Ez_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_yz.npy',Ex_yz)
np.save('DFT_GAS/Dft_GAS_Ey_yz.npy',Ey_yz)
np.save('DFT_GAS/Dft_GAS_Ez_yz.npy',Ez_yz)

Ex01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ex,0)
Ey01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ey,0)
Ez01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_xyz1.npy',Ex01)
np.save('DFT_GAS/Dft_GAS_Ey_xyz1.npy',Ey01)
np.save('DFT_GAS/Dft_GAS_Ez_xyz1.npy',Ez01)

Ex00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ex,0)
Ey00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ey,0)
Ez00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_xyz0.npy',Ex00)
np.save('DFT_GAS/Dft_GAS_Ey_xyz0.npy',Ey00)
np.save('DFT_GAS/Dft_GAS_Ez_xyz0.npy',Ez00)

Ex_mode_volume = opt.sim.get_dft_array(dft_fields_mode_volume,mp.Ex,0)
Ey_mode_volume = opt.sim.get_dft_array(dft_fields_mode_volume,mp.Ey,0)
Ez_mode_volume = opt.sim.get_dft_array(dft_fields_mode_volume,mp.Ez,0)
np.save('DFT_mode_volume/DFT_mode_volume_Ex_xyz0.npy',Ex00)
np.save('DFT_mode_volume/DFT_mode_volume_Ey_xyz0.npy',Ey00)
np.save('DFT_mode_volume/DFT_mode_volume_Ez_xyz0.npy',Ez00)
